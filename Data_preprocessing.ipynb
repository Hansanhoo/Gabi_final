# %% [markdown]
# # Data Preprocessing

# %%
from pyspark.sql import SparkSession
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql.functions import isnan, when, count, col, sequence, date_format, UserDefinedFunction
from datetime import datetime
import pandas as pd
from pyspark.sql.types import  (StructType, 
                                StructField, 
                                DateType, 
                                BooleanType,
                                DoubleType,
                                IntegerType,
                                StringType,
                               TimestampType)
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.stat import Correlation
from pyspark.sql.types import IntegerType
import numpy as np
import seaborn as sns
from pyspark.ml.classification import MultilayerPerceptronClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pymongo import MongoClient
from fbprophet import Prophet
from pyspark.sql.functions import current_date
import re
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
conn = MongoClient("mongo", 27017)
db = conn.mydb
collection_crime = db.chicago_crime
collection_crime_clean = db.chicago_crime_cleaned
collection_primary_type = db.primary_type
collection_location_description = db.location_description
collection_description = db.description

# %% [markdown]
# ### Initialize Spark Session

# %%
spark = SparkSession.\
        builder.\
        appName("pysparkapp").\
        master("spark://spark-master:7077").\
        config("spark.executor.memory", "2g").\
        config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.0").\
        getOrCreate()

# %% [markdown]
# ### Read data from Mongo DB

# %%
df = spark.read.format("mongo").option("uri","mongodb://mongo:27017/mydb.chicago_crime").load()

# %%
df.printSchema()
# Out:
# root
#  |-- _id: struct (nullable = true)
#  |    |-- oid: string (nullable = true)
#  |-- arrest: boolean (nullable = true)
#  |-- beat: string (nullable = true)
#  |-- block: string (nullable = true)
#  |-- case_number: string (nullable = true)
#  |-- community_area: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- domestic: boolean (nullable = true)
#  |-- fbi_code: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- iucr: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- location: struct (nullable = true)
#  |    |-- latitude: string (nullable = true)
#  |    |-- longitude: string (nullable = true)
#  |    |-- human_address: string (nullable = true)
#  |-- location_description: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- primary_type: string (nullable = true)
#  |-- updated_on: string (nullable = true)
#  |-- ward: string (nullable = true)
#  |-- x_coordinate: string (nullable = true)
#  |-- y_coordinate: string (nullable = true)
#  |-- year: string (nullable = true)

# %%
# count the entrys in the dataframe
df.cache()
df.count()
# Out:
# 7273203

# %%
df.show(10)
# Out:
# +--------------------+------+----+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+--------+--------+----+------------+--------------------+--------------------+-------------+--------------------+--------------------+----+------------+------------+----+
# |                 _id|arrest|beat|               block|case_number|community_area|                date|         description|district|domestic|fbi_code|      id|iucr|    latitude|            location|location_description|    longitude|        primary_type|          updated_on|ward|x_coordinate|y_coordinate|year|
# +--------------------+------+----+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+--------+--------+----+------------+--------------------+--------------------+-------------+--------------------+--------------------+----+------------+------------+----+
# |[5ff9814953230ace...| false|2032| 050XX N ASHLAND AVE|   JB152500|             3|2001-01-01T00:00:...|AGG SEX ASSLT OF ...|     020|   false|      02|11231026|1754|        null|                null|           RESIDENCE|         null|OFFENSE INVOLVING...|2018-10-27T16:00:...|  47|        null|        null|2001|
# |[5ff9814a53230ace...| false|1421|   018XX N TALMAN AV|    G055473|          null|2001-01-01T00:00:...|      $500 AND UNDER|     014|   false|      06| 1352564|0820|41.914955409|[41.914955409, -8...|              STREET|-87.693605188|               THEFT|2015-08-17T15:03:...|null|     1158368|     1912249|2001|
# |[5ff9814a53230ace...| false|1123|    034XX W ADAMS ST|    G057402|          null|2001-01-01T00:00:...|   CREDIT CARD FRAUD|     011|   false|      11| 1353509|1150| 41.87821192|[41.87821192, -87...|           RESIDENCE|-87.711432075|  DECEPTIVE PRACTICE|2015-08-17T15:03:...|null|     1153613|     1898824|2001|
# |[5ff9814a53230ace...| false|1711|  062XX N PULASKI RD|    G061760|          null|2001-01-01T00:00:...|   CREDIT CARD FRAUD|     017|   false|      11| 1357088|1150|41.995267432|[41.995267432, -8...|  SMALL RETAIL STORE|-87.729044138|  DECEPTIVE PRACTICE|2015-08-17T15:03:...|null|     1148516|     1941445|2001|
# |[5ff9814a53230ace...| false|2535|012XX N SPRINGFIE...|    G067736|          null|2001-01-01T00:00:...|              SIMPLE|     025|   false|     08A| 1362018|0560|41.903597909|[41.903597909, -8...|           RESIDENCE|-87.724042825|             ASSAULT|2015-08-17T15:03:...|null|     1150113|     1908050|2001|
# |[5ff9814a53230ace...| false|2313|045XX N CLARENDON AV|    G000065|          null|2001-01-01T00:00:...|          TO VEHICLE|     019|   false|      14| 1309885|1320|41.963705611|[41.963705611, -8...|              STREET|-87.650116531|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|     1170063|     1930105|2001|
# |[5ff9814a53230ace...| false|2112|  026XX S INDIANA AV|    G000355|          null|2001-01-01T00:00:...|         TO PROPERTY|     002|   false|      14| 1309913|1310|41.844745115|[41.844745115, -8...|           APARTMENT|-87.621968071|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|     1178078|     1886818|2001|
# |[5ff9814a53230ace...| false|0834|       036XX W 80 ST|    G000610|          null|2001-01-01T00:00:...|          TO VEHICLE|     008|   false|      14| 1310162|1320|41.747712773|[41.747712773, -8...|              STREET|-87.712370684|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|     1153701|     1851269|2001|
# |[5ff9814a53230ace...| false|2212| 109XX S LONGWOOD DR|    G000070|          null|2001-01-01T00:00:...|         TO PROPERTY|     022|   false|      14| 1310313|1310|41.694977232|[41.694977232, -8...|           APARTMENT|-87.671447845|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|     1165016|     1832136|2001|
# |[5ff9814a53230ace...| false|1831| 0000X W ILLINOIS ST|    G000802|          null|2001-01-01T00:00:...|          TO VEHICLE|     018|   false|      14| 1310494|1320|41.890741624|[41.890741624, -8...|PARKING LOT/GARAG...|-87.628671125|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|     1176114|     1903564|2001|
# +--------------------+------+----+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+--------+--------+----+------------+--------------------+--------------------+-------------+--------------------+--------------------+----+------------+------------+----+
# only showing top 10 rows

# %% [markdown]
# ### Drop columns which are not needed

# %%
df = df.drop('_id')
df = df.drop('x_coordinate')
df = df.drop('y_coordinate')
df = df.drop('beat')
df = df.drop('fbi_code')
df = df.drop('location')
df = df.drop('id')
df = df.drop('iucr')

# %%
df.printSchema()
# Out:
# root
#  |-- arrest: boolean (nullable = true)
#  |-- block: string (nullable = true)
#  |-- case_number: string (nullable = true)
#  |-- community_area: string (nullable = true)
#  |-- date: string (nullable = true)
#  |-- description: string (nullable = true)
#  |-- district: string (nullable = true)
#  |-- domestic: boolean (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- location_description: string (nullable = true)
#  |-- longitude: string (nullable = true)
#  |-- primary_type: string (nullable = true)
#  |-- updated_on: string (nullable = true)
#  |-- ward: string (nullable = true)
#  |-- year: string (nullable = true)

# %% [markdown]
# ## Convert the strings Types into numeric values

# %% [markdown]
# Convert the columne description into int

# %%
#select unique descriptions
unique_descriptions = df.select("description").distinct().collect()

# %%
unique_descriptions
# Out:
# [Row(description='UNLAWFUL USE OF A COMPUTER'),
#  Row(description='AGGRAVATED PO:KNIFE/CUT INSTR'),
#  Row(description='AGGRAVATED: OTHER DANG WEAPON'),
#  Row(description='POSS: COCAINE'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='ATTEMPT POSSESSION CANNABIS'),
#  Row(description='POSSESSION: SYNTHETIC MARIJUANA'),
#  Row(description='POSSESS - SYNTHETIC DRUGS'),
#  Row(description='OVER $500'),
#  Row(description='DEFACE IDENT MARKS OF FIREARM'),
#  Row(description='SEX OFFENDER - FAIL TO REGISTER'),
#  Row(description='VIOLENT OFFENDER - DUTY TO REGISTER'),
#  Row(description='DISCLOSE DV VICTIM LOCATION'),
#  Row(description='JUVENILE PIMPING'),
#  Row(description='COMPELLING CONFESSION'),
#  Row(description='ATTEMPT STRONG ARM - NO WEAPON'),
#  Row(description='UNLAWFUL USE - OTHER DANGEROUS WEAPON'),
#  Row(description='ATTEMPT FINANCIAL IDENTITY THEFT'),
#  Row(description='CRIMINAL TRANSMISSION OF HIV'),
#  Row(description='BY EXPLOSIVE'),
#  Row(description='ARSONIST: DUTY TO REGISTER'),
#  Row(description='AGGRAVATED POLICE OFFICER - HANDGUN'),
#  Row(description='BOGUS CHECK'),
#  Row(description='UNLAWFUL USE OF BODY ARMOR'),
#  Row(description='NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES'),
#  Row(description='THEFT OF LOST / MISLAID PROPERTY'),
#  Row(description='POSSESS - COCAINE'),
#  Row(description='OTHER CRIME INVOLVING PROPERTY'),
#  Row(description='FINANCIAL IDENTITY THEFT $300 AND UNDER'),
#  Row(description='CONTRIBUTE CRIM DELINQUENCY JUVENILE'),
#  Row(description='AGG CRIMINAL SEXUAL ABUSE'),
#  Row(description='CRIM SEX ABUSE BY FAM MEMBER'),
#  Row(description='MARRYING A BIGAMIST'),
#  Row(description='POSS: LOOK-ALIKE DRUGS'),
#  Row(description='REFUSING TO AID AN OFFICER'),
#  Row(description='POSSESSION OF PORNOGRAPHIC PRINT'),
#  Row(description='COMPUTER FRAUD'),
#  Row(description='FAILURE TO KEEP HYPO RECORDS'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM'),
#  Row(description='ARSONIST - FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='FIREARM REGISTRATION VIOLATION'),
#  Row(description='UNLAWFUL SALE HANDGUN'),
#  Row(description='OBSTRUCTING SERVICE'),
#  Row(description='THEFT / RECOVERY - AUTOMOBILE'),
#  Row(description='FINANCIAL IDENTITY THEFT: OVER $300'),
#  Row(description='DELIVERY CONTAINER THEFT'),
#  Row(description='BIGAMY'),
#  Row(description='WIREROOM/HORSES'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: KNIFE / CUTTING INSTSTRUMENT'),
#  Row(description='AGG PO HANDS NO/MIN INJURY'),
#  Row(description='OTHER CRIME AGAINST PERSON'),
#  Row(description='ATTEMPT: AGGRAVATED'),
#  Row(description='MANUFACTURE / DELIVER - HALLUCINOGEN'),
#  Row(description='THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN'),
#  Row(description='FINANCIAL IDENTITY THEFT OVER $ 300'),
#  Row(description='VIOLATION OF SUMMARY CLOSURE'),
#  Row(description='DELIVER CANNABIS TO PERSON <18'),
#  Row(description='AGGRAVATED OF AN UNBORN CHILD'),
#  Row(description='THEFT/RECOVERY: CYCLE, SCOOTER, BIKE NO VIN'),
#  Row(description='ATTEMPT - FINANCIAL IDENTITY THEFT'),
#  Row(description='CONT SUBS:FAIL TO MAINT RECORD'),
#  Row(description='AIDING ARRESTEE ESCAPE'),
#  Row(description='CHILD ABDUCTION'),
#  Row(description='RECKLESS CONDUCT'),
#  Row(description='SALE/DIST OBSCENE MAT TO MINOR'),
#  Row(description='EMPLOY MINOR'),
#  Row(description='MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS'),
#  Row(description='VIOLATE ORDER OF PROTECTION'),
#  Row(description='INSTITUTIONAL VANDALISM'),
#  Row(description='GUN OFFENDER - ANNUAL REGISTRATION'),
#  Row(description='STRONGARM: NO WEAPON'),
#  Row(description='ATTEMPT - TRUCK, BUS, MOTOR HOME'),
#  Row(description='UNLAWFUL POSS OF HANDGUN'),
#  Row(description='ATT: TRUCK, BUS, MOTOR HOME'),
#  Row(description='MANU/DELIVER:AMPHETAMINES'),
#  Row(description='MANU/DELIVER:HEROIN(BLACK TAR)'),
#  Row(description='PROHIBITED PLACES'),
#  Row(description='MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)'),
#  Row(description='MANUFACTURE / DELIVER - METHAMPHETAMINE'),
#  Row(description='POSS: SYNTHETIC DRUGS'),
#  Row(description='UNAUTHORIZED VIDEOTAPING'),
#  Row(description='OBSCENITY'),
#  Row(description='TO LAND'),
#  Row(description='FORCIBLE ENTRY'),
#  Row(description='UNLAWFUL SALE - HANDGUN'),
#  Row(description='MANU/DEL:CANNABIS OVER 10 GMS'),
#  Row(description='ATTEMPT ARMED - HANDGUN'),
#  Row(description='AGGRAVATED FINANCIAL IDENTITY THEFT'),
#  Row(description='CALL OPERATION'),
#  Row(description='FORFEIT PROPERTY'),
#  Row(description='POS: EXPLOSIVE/INCENDIARY DEV'),
#  Row(description='ARMED - HANDGUN'),
#  Row(description='AGG: HANDS/FIST/FEET SERIOUS INJURY'),
#  Row(description='SEX OFFENDER: FAIL REG NEW ADD'),
#  Row(description='SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='MANU/DELIVER: HEROIN (WHITE)'),
#  Row(description='ATTEMPT FORCIBLE ENTRY'),
#  Row(description='ILLEGAL POSSESSION CASH CARD'),
#  Row(description='FRAUD OR CONFIDENCE GAME'),
#  Row(description='PAY TV SERVICE OFFENSES'),
#  Row(description='POSSESS - AMPHETAMINES'),
#  Row(description='AGG: FINANCIAL ID THEFT'),
#  Row(description='FALSE/STOLEN/ALTERED TRP'),
#  Row(description='THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN'),
#  Row(description='TO VEHICLE'),
#  Row(description='THEFT BY LESSEE,NON-VEH'),
#  Row(description='THEFT BY LESSEE,MOTOR VEH'),
#  Row(description='CONCEALED CARRY LICENSE REVOCATION'),
#  Row(description='ATTEMPT AGG: OTHER DANG WEAPON'),
#  Row(description='UNLAWFUL INTERFERE/VISITATION'),
#  Row(description='PATRONIZING A PROSTITUTE'),
#  Row(description='PROBATION VIOLATION'),
#  Row(description='MANU/DELIVER: HALLUCINOGEN'),
#  Row(description='AGGRAVATED: OTHER FIREARM'),
#  Row(description='CRIMINAL DRUG CONSPIRACY'),
#  Row(description='ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE'),
#  Row(description='SOLICIT ON PUBLIC WAY'),
#  Row(description='CHILD ABANDONMENT'),
#  Row(description='OF UNBORN CHILD'),
#  Row(description='MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA'),
#  Row(description='INVOLUNTARY SERVITUDE'),
#  Row(description='AGGRAVATED: HANDGUN'),
#  Row(description='CAB OPERATION'),
#  Row(description='SELL/ADVERTISE FIREWORKS'),
#  Row(description='ATTEMPT ARMED - OTHER DANGEROUS WEAPON'),
#  Row(description='ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN'),
#  Row(description='ARMED: OTHER DANGEROUS WEAPON'),
#  Row(description='MANU/DELIVER:PCP'),
#  Row(description='ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='PREDATORY'),
#  Row(description='ABUSE/NEGLECT: CARE FACILITY'),
#  Row(description='FOUND SUSPECT NARCOTICS'),
#  Row(description='MANU/DELIVER: HEROIN(BRN/TAN)'),
#  Row(description='ATTEMPT: CYCLE, SCOOTER, BIKE NO VIN'),
#  Row(description='ATTEMPT AGGRAVATED - HANDGUN'),
#  Row(description='TO PROPERTY'),
#  Row(description='STRONG ARM - NO WEAPON'),
#  Row(description='LIBRARY THEFT'),
#  Row(description='FORNICATION'),
#  Row(description='ATTEMPT AGG: HANDGUN'),
#  Row(description='VIOLENT OFFENDER: ANNUAL REGISTRATION'),
#  Row(description='PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY'),
#  Row(description='PEEPING TOM'),
#  Row(description='POSSESS - HALLUCINOGENS'),
#  Row(description='DOMESTIC VIOLENCE'),
#  Row(description='SPORTS TAMPERING'),
#  Row(description='AGG: HANDS/FIST/FEET NO/MINOR INJURY'),
#  Row(description='$300 AND UNDER'),
#  Row(description='THEFT RETAIL'),
#  Row(description='POSS: CANNABIS MORE THAN 30GMS'),
#  Row(description='ANIMAL ABUSE/NEGLECT'),
#  Row(description='GUN OFFENDER: DUTY TO REGISTER'),
#  Row(description='POCKET-PICKING'),
#  Row(description='EAVESDROPPING'),
#  Row(description='ANIMAL FIGHTING'),
#  Row(description='COMPOUNDING A CRIME'),
#  Row(description='VIOLATION OF SMOKING BAN'),
#  Row(description='PATRONIZE JUVENILE PROSTITUTE'),
#  Row(description='OBSTRUCTING JUSTICE'),
#  Row(description='ATTEMPT: ARMED-OTHER DANG WEAP'),
#  Row(description='AGG PRO.EMP: OTHER DANG WEAPON'),
#  Row(description='OBSCENE TELEPHONE CALLS'),
#  Row(description='BRIBERY'),
#  Row(description='POSSESS - METHAMPHETAMINE'),
#  Row(description='MANUFACTURE / DELIVER - PCP'),
#  Row(description='FINAN EXPLOIT-ELDERLY/DISABLED'),
#  Row(description='DEL CONT SUBS TO PERSON <18'),
#  Row(description='CANNABIS PLANT'),
#  Row(description='INTERFERE W/ HIGHER EDUCATION'),
#  Row(description='AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='POS: CHEMICAL/DRY-ICE DEVICE'),
#  Row(description='AGG PRO.EMP:KNIFE/CUTTING INST'),
#  Row(description='INDECENT SOLICITATION/CHILD'),
#  Row(description='AGGRAVATED PO: OTHER FIREARM'),
#  Row(description='ILLEGAL POSSESSION BY MINOR'),
#  Row(description='CONTRIBUTE TO THE DELINQUENCY OF CHILD'),
#  Row(description='AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY'),
#  Row(description='CONTRABAND IN PRISON'),
#  Row(description='FALSE / STOLEN / ALTERED TRP'),
#  Row(description='AGGRAVATED:KNIFE/CUTTING INSTR'),
#  Row(description='BOMB THREAT'),
#  Row(description='ATTEMPT ARSON'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST'),
#  Row(description='UNLAWFUL USE OTHER FIREARM'),
#  Row(description='INTOXICATING COMPOUNDS'),
#  Row(description='MANUFACTURE / DELIVER - COCAINE'),
#  Row(description='INTERFERE WITH EMERGENCY EQUIPMENT'),
#  Row(description='ATTEMPT AGG: OTHER FIREARM'),
#  Row(description='ATTEMPT: STRONGARM-NO WEAPON'),
#  Row(description='PIMPING'),
#  Row(description='PURSE-SNATCHING'),
#  Row(description='AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='INSURANCE FRAUD'),
#  Row(description='USE OF METAL PIERCING BULLETS'),
#  Row(description='$500 AND UNDER'),
#  Row(description='AGG RITUAL MUT:KNIFE/CUTTING I'),
#  Row(description='SEXUAL RELATIONS IN FAMILY'),
#  Row(description='POSSESS - CANNABIS MORE THAN 30 GRAMS'),
#  Row(description='ATT: AUTOMOBILE'),
#  Row(description='VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='AGGRAVATED: OTHER'),
#  Row(description='GAME/CARDS'),
#  Row(description='ADULTRY'),
#  Row(description='ANIMAL ABUSE / NEGLECT'),
#  Row(description='OF AN UNBORN CHILD'),
#  Row(description='GAME/DICE'),
#  Row(description='COUNTERFEIT CHECK'),
#  Row(description='SOLICIT FOR PROSTITUTE'),
#  Row(description='AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='UNLAWFUL USE/SALE AIR RIFLE'),
#  Row(description='POS: HYPODERMIC NEEDLE'),
#  Row(description='AUTOMOBILE'),
#  Row(description='ARSONIST - ANNUAL REGISTRATION'),
#  Row(description='ESCAPE'),
#  Row(description='ATTEMPT AGG: OTHER'),
#  Row(description='AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON'),
#  Row(description='UNLAWFUL USE - OTHER FIREARM'),
#  Row(description='INDECENT SOLICITATION OF AN ADULT'),
#  Row(description='AGGRAVATED VEHICULAR HIJACKING'),
#  Row(description='FINANCIAL ID THEFT:$300 &UNDER'),
#  Row(description='MANU/DELIVER: METHAMPHETAMINES'),
#  Row(description='TELEPHONE THREAT'),
#  Row(description='SEXUAL EXPLOITATION OF A CHILD'),
#  Row(description='FALSE POLICE REPORT'),
#  Row(description='SALE/DEL HYPODERMIC NEEDLE'),
#  Row(description='DOMESTIC BATTERY SIMPLE'),
#  Row(description='LOTTERY/OTHER'),
#  Row(description='MANUFACTURE / DELIVER - SYNTHETIC DRUGS'),
#  Row(description='LOOTING'),
#  Row(description='FOUND PASSPORT'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - OTHER FIREARM'),
#  Row(description='CHILD PORNOGRAPHY'),
#  Row(description='KEEP PLACE OF PROSTITUTION'),
#  Row(description='AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY'),
#  Row(description='UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL'),
#  Row(description='OBSTRUCTING IDENTIFICATION'),
#  Row(description='UNLAWFUL SALE OTHER FIREARM'),
#  Row(description='ATTEMPT CRIMINAL SEXUAL ABUSE'),
#  Row(description='GUN OFFENDER - DUTY TO REGISTER'),
#  Row(description='THEFT BY LESSEE, NON-MOTOR VEHICLE'),
#  Row(description='TRUCK, BUS, MOTOR HOME'),
#  Row(description='POSS: AMPHETAMINES'),
#  Row(description='OVER $300'),
#  Row(description='INTERFERE W/ EMERGENCY EQUIP'),
#  Row(description='NOTIFICATION OF CIVIL NO CONTACT ORDER'),
#  Row(description='ARMED: HANDGUN'),
#  Row(description='SOLICIT NARCOTICS ON PUBLICWAY'),
#  Row(description='LIBRARY VANDALISM'),
#  Row(description='AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY'),
#  Row(description='FALSE FIRE ALARM'),
#  Row(description='SEX OFFENDER: PROHIBITED ZONE'),
#  Row(description='BOOKMAKING/HORSES'),
#  Row(description='POSS: HEROIN(BLACK TAR)'),
#  Row(description='SOLICIT OFF PUBLIC WAY'),
#  Row(description='HARASSMENT BY ELECTRONIC MEANS'),
#  Row(description='UNLAWFUL USE OF RECORDED SOUND'),
#  Row(description='AGGRAVATED - HANDGUN'),
#  Row(description='POS: PORNOGRAPHIC PRINT'),
#  Row(description='POSSESS - HEROIN (WHITE)'),
#  Row(description='CYCLE, SCOOTER, BIKE WITH VIN'),
#  Row(description='MANU/DELIVER:SYNTHETIC DRUGS'),
#  Row(description='CONCEALING/AIDING A FUGITIVE'),
#  Row(description='HARASSMENT BY TELEPHONE'),
#  Row(description='AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'),
#  Row(description='TAMPER WITH MOTOR VEHICLE'),
#  Row(description='UNLAWFUL POSSESSION - HANDGUN'),
#  Row(description='INVOLUNTARY MANSLAUGHTER'),
#  Row(description='WIREROOM/SPORTS'),
#  Row(description='UNLAWFUL POSS AMMUNITION'),
#  Row(description='EXTORTION'),
#  Row(description='AGGRAVATED - OTHER FIREARM'),
#  Row(description='ABUSE / NEGLECT - CARE FACILITY'),
#  Row(description='UNLAWFUL USE HANDGUN'),
#  Row(description='HAZARDOUS MATERIALS VIOLATION'),
#  Row(description='FAIL REGISTER LIC:CONT SUBS'),
#  Row(description='AGG SEX ASSLT OF CHILD FAM MBR'),
#  Row(description='UNLAWFUL POSS OTHER FIREARM'),
#  Row(description='AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#  Row(description='ATTEMPT - AUTOMOBILE'),
#  Row(description='OTHER WEAPONS VIOLATION'),
#  Row(description='AGGRAVATED OF A CHILD'),
#  Row(description='MANUFACTURE / DELIVER -  HEROIN (WHITE)'),
#  Row(description='FORGERY'),
#  Row(description='ILLEGAL ILL LOTTERY'),
#  Row(description='INTERFERENCE JUDICIAL PROCESS'),
#  Row(description='OTHER ARSON/EXPLOSIVE INCIDENT'),
#  Row(description='VEHICLE TITLE/REG OFFENSE'),
#  Row(description='PUBLIC DEMONSTRATION'),
#  Row(description='NOTIFICATION OF STALKING - NO CONTACT ORDER'),
#  Row(description='POSSESS - BARBITURATES'),
#  Row(description='UNLAWFUL RESTRAINT'),
#  Row(description='POSS: METHAMPHETAMINES'),
#  Row(description='AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON'),
#  Row(description='ILLEGAL USE CASH CARD'),
#  Row(description='MANU/DELIVER:BARBITUATES'),
#  Row(description='LICENSE VIOLATION'),
#  Row(description='FOID - REVOCATION'),
#  Row(description='POSSESS - HEROIN (TAN / BROWN TAR)'),
#  Row(description='POSS: HALLUCINOGENS'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY'),
#  Row(description='VEHICULAR HIJACKING'),
#  Row(description='AGGRAVATED PO: KNIFE/CUT INSTR'),
#  Row(description='ATT AGG CRIM SEXUAL ABUSE'),
#  Row(description='POSSESSION OF DRUG EQUIPMENT'),
#  Row(description='AGGRAVATED PO: HANDGUN'),
#  Row(description='AGG PRO EMP HANDS SERIOUS INJ'),
#  Row(description='RECKLESS FIREARM DISCHARGE'),
#  Row(description='FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON'),
#  Row(description='GUN OFFENDER NOTIFICATION-NO CONTACT'),
#  Row(description='MANUFACTURE / DELIVER - CRACK'),
#  Row(description='AGGRAVATED: KNIFE / CUTTING INSTRUMENT'),
#  Row(description='STOLEN PROPERTY BUY / RECEIVE / POSSESS'),
#  Row(description='AGGRAVATED PROTECTED EMPLOYEE - HANDGUN'),
#  Row(description='POSS: CRACK'),
#  Row(description='FROM BUILDING'),
#  Row(description='IMPERSONATION'),
#  Row(description='TO AIRPORT'),
#  Row(description='POLICY/OTHER'),
#  Row(description='MANU/DELIVER:CRACK'),
#  Row(description='LOTTERY/PARLAY CARDS'),
#  Row(description='FROM COIN-OPERATED MACHINE OR DEVICE'),
#  Row(description='AGGRAVATED: HANDS / FIST / FEET SERIOUS INJURY'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON'),
#  Row(description='MANUFACTURE / DELIVER - AMPHETAMINES'),
#  Row(description='GUN OFFENDER - DUTY TO REPORT CHANGE OF INFORMATION'),
#  Row(description='SOLICITING FOR BUSINESS'),
#  Row(description='AGG RITUAL MUT:OTH DANG WEAPON'),
#  Row(description='VIOL CHARITABLE GAME ACT'),
#  Row(description='VEHICLE TITLE / REGISTRATION OFFENSE'),
#  Row(description='ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON'),
#  Row(description='SEX RELATION IN FAMILY'),
#  Row(description='AGGRAVATED OF A UNBORN CHILD'),
#  Row(description='PUBLIC INDECENCY'),
#  Row(description='AGGRAVATED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='EDUCATIONAL INTIMIDAITON'),
#  Row(description='SALE / DELIVER - DRUG PARAPHERNALIA'),
#  Row(description='LICENSED PREMISE'),
#  Row(description='GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION'),
#  Row(description='ALTER/FORGE PRESCRIPTION'),
#  Row(description='TO FIRE FIGHT.APP.EQUIP'),
#  Row(description='AGGRAVATED CRIMINAL SEXUAL ABUSE'),
#  Row(description='RESIST / OBSTRUCT / DISARM OFFICER'),
#  Row(description='SOLICITING FOR A PROSTITUTE'),
#  Row(description='POSS: HEROIN(WHITE)'),
#  Row(description='RETAIL THEFT'),
#  Row(description='AGG CRIM SEX ABUSE FAM MEMBER'),
#  Row(description='SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'),
#  Row(description='BY FIRE'),
#  Row(description='AGGRAVATED PO: OTHER DANGEROUS WEAPON'),
#  Row(description='UNLAWFUL USE / SALE OF AIR RIFLE'),
#  Row(description='REGISTER FED GAMBLING STAMP'),
#  Row(description='MANU/DEL:CANNABIS 10GM OR LESS'),
#  Row(description='BOLITA OR BOLI PUL/OFFICE'),
#  Row(description='AGGRAVATED P.O. - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='SALE TOBACCO PRODUCTS TO MINOR'),
#  Row(description='TO STATE SUPPORTED PROPERTY'),
#  Row(description='ATTEMPT ARMED - OTHER FIREARM'),
#  Row(description='OTHER VIOLATION'),
#  Row(description='AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY'),
#  Row(description='THEFT OF LABOR / SERVICES'),
#  Row(description='INDECENT SOLICITATION OF A CHILD'),
#  Row(description='SOLICIT FOR BUSINESS'),
#  Row(description='DECEPTIVE COLLECTION PRACTICES'),
#  Row(description='LOST PASSPORT'),
#  Row(description='THEFT OF LABOR/SERVICES'),
#  Row(description='ATTEMPT: ARMED-HANDGUN'),
#  Row(description='CALCULATED CANNABIS CONSPIRACY'),
#  Row(description='MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS'),
#  Row(description='DEFACE IDENTIFICATION MARKS OF FIREARM'),
#  Row(description='MANU/DELIVER:COCAINE'),
#  Row(description='OTHER'),
#  Row(description='UNLAWFUL USE - HANDGUN'),
#  Row(description='ENDANGERING LIFE/HEALTH CHILD'),
#  Row(description='IN TAVERN'),
#  Row(description='AGGRAVATED: KNIFE/CUT INSTR'),
#  Row(description='POSSESS FIREARM / AMMUNITION - NO FOID CARD'),
#  Row(description='CONTRIBUTE TO THE CRIMINAL DELINQUENCY OF CHILD'),
#  Row(description='THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME'),
#  Row(description='ARMED - OTHER DANGEROUS WEAPON'),
#  Row(description='ATTEMPT ARMED: HANDGUN'),
#  Row(description='INTIMIDATION'),
#  Row(description='OBSCENE MATTER'),
#  Row(description='ARMED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='CRIMINAL DEFACEMENT'),
#  Row(description='TO CITY OF CHICAGO PROPERTY'),
#  Row(description='INDECENT SOLICITATION/ADULT'),
#  Row(description='POSSESS - CANNABIS 30 GRAMS OR LESS'),
#  Row(description='POSSESSION - EXPLOSIVE / INCENDIARY DEVICE'),
#  Row(description='NATIONAL LOTTERY'),
#  Row(description='CREDIT CARD FRAUD'),
#  Row(description='FINANCIAL ID THEFT: OVER $300'),
#  Row(description='FROM COIN-OP MACHINE/DEVICE'),
#  Row(description='ATTEMPT AGGRAVATED - OTHER'),
#  Row(description='NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES'),
#  Row(description='ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='GAME / AMUSEMENT DEVICE'),
#  Row(description='MANU/DELIVER:LOOK-ALIKE DRUG'),
#  Row(description='TO STATE SUP PROP'),
#  Row(description='GUN OFFENDER: ANNUAL REGISTRATION'),
#  Row(description='SELL/GIVE/DEL LIQUOR TO MINOR'),
#  Row(description='ATTEMPT: ARMED-OTHER FIREARM'),
#  Row(description='ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN'),
#  Row(description='BOLITA OR BOLI PUL/RUNNER'),
#  Row(description='ALTER COINS'),
#  Row(description='VIOLATION OF CIVIL NO CONTACT ORDER'),
#  Row(description='UNLAWFUL USE OTHER DANG WEAPON'),
#  Row(description='EMBEZZLEMENT'),
#  Row(description='BOLITA OR BOLI PUL/WRITER'),
#  Row(description='ATT AGG CRIMINAL SEXUAL ABUSE'),
#  Row(description='BOARD PLANE WITH WEAPON'),
#  Row(description='RECKLESS HOMICIDE'),
#  Row(description='MANUFACTURE / DELIVER - BARBITURATES'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: HANDGUN'),
#  Row(description='VIOLATION OF STALKING NO CONTACT ORDER'),
#  Row(description='LIQUOR LICENSE VIOLATION'),
#  Row(description='AGGRAVATED'),
#  Row(description='SALE/DEL DRUG PARAPHERNALIA'),
#  Row(description='VIOLENT OFFENDER: DUTY TO REGISTER'),
#  Row(description='UNLAWFUL POSSESSION - AMMUNITION'),
#  Row(description='COUNTERFEITING DOCUMENT'),
#  Row(description='CHILD ABDUCTION/STRANGER'),
#  Row(description='SEX ASSLT OF CHILD BY FAM MBR'),
#  Row(description='OTHER VEHICLE OFFENSE'),
#  Row(description='VIO BAIL BOND: DOM VIOLENCE'),
#  Row(description='POSSESSION OF BURGLARY TOOLS'),
#  Row(description='UNIDENTIFIABLE RECORDING SOUND'),
#  Row(description='STRONGARM - NO WEAPON'),
#  Row(description='ARMED - OTHER FIREARM'),
#  Row(description='POSSESS - CRACK'),
#  Row(description='POSSESS - PCP'),
#  Row(description='ARMED: OTHER FIREARM'),
#  Row(description='PRO EMP HANDS NO/MIN INJURY'),
#  Row(description='AGGRAVATED - OTHER'),
#  Row(description='SOLICIT NARCOTICS ON PUBLIC WAY'),
#  Row(description='AGG PO HANDS ETC SERIOUS INJ'),
#  Row(description='AGGRAVATED POLICE OFFICER - OTHER FIREARM'),
#  Row(description='AGGRAVATED OF A SENIOR CITIZEN'),
#  Row(description='THEFT/RECOVERY: AUTOMOBILE'),
#  Row(description='ILLEGAL CONSUMPTION BY MINOR'),
#  Row(description='MOB ACTION'),
#  Row(description='COMPELLING ORG MEMBERSHIP'),
#  Row(description='FIRST DEGREE MURDER'),
#  Row(description='VIOLATION GPS MONITORING DEVICE'),
#  Row(description='UNLAWFUL POSSESSION - OTHER FIREARM'),
#  Row(description='KEEP PLACE OF JUV PROSTITUTION'),
#  Row(description='MONEY LAUNDERING'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - HANDGUN'),
#  Row(description='AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY'),
#  Row(description='AGGRAVATED - OTHER DANGEROUS WEAPON'),
#  Row(description='ARSONIST: ANNUAL REGISTRATION'),
#  Row(description='UNLAWFUL ENTRY'),
#  Row(description='POSS FIREARM/AMMO:NO FOID CARD'),
#  Row(description='OTHER ARSON / EXPLOSIVE INCIDENT'),
#  Row(description='NON-AGGRAVATED'),
#  Row(description='ARSON THREAT'),
#  Row(description='CHILD ABUSE'),
#  Row(description='ARMED:KNIFE/CUTTING INSTRUMENT'),
#  Row(description='POSS. KEYS OR DEV.TO COIN MACH'),
#  Row(description='CYBERSTALKING'),
#  Row(description='CRIMINAL SEXUAL ABUSE'),
#  Row(description='AGG PRO.EMP: HANDGUN'),
#  Row(description='THEFT BY LESSEE, MOTOR VEHICLE'),
#  Row(description='VIOLENT OFFENDER - FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='BOOKMAKING/SPORTS'),
#  Row(description='MINOR MISREPRESENT AGE'),
#  Row(description='AGG PRO.EMP: OTHER FIREARM'),
#  Row(description='ARMED WHILE UNDER THE INFLUENCE'),
#  Row(description='ATTEMPT: ARMED-KNIFE/CUT INSTR'),
#  Row(description='COMMERCIAL SEX ACTS'),
#  Row(description='STOLEN PROP: BUY/RECEIVE/POS.'),
#  Row(description='CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#  Row(description='THEFT/RECOVERY: TRUCK,BUS,MHOME'),
#  Row(description='ATTEMPT POSSESSION NARCOTICS'),
#  Row(description='AGGRAVATED COMPUTER TAMPERING'),
#  Row(description='POSS: HEROIN(BRN/TAN)'),
#  Row(description='OTHER OFFENSE'),
#  Row(description='ARMED VIOLENCE'),
#  Row(description='LOTTERY/PARI-MUTUEL'),
#  Row(description='ATT CRIM SEXUAL ABUSE'),
#  Row(description='ENDANGERING LIFE / HEALTH OF CHILD'),
#  Row(description='ALTER / FORGE PRESCRIPTION'),
#  Row(description='ARSONIST: FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='TO STATE SUP LAND'),
#  Row(description='OFFICIAL MISCONDUCT'),
#  Row(description='ATTEMPT THEFT'),
#  Row(description='CYCLE, SCOOTER, BIKE W-VIN'),
#  Row(description='PANDERING'),
#  Row(description='AGG RITUAL MUT:HANDGUN'),
#  Row(description='AGGRAVATED: OTHER DANGEROUS WEAPON'),
#  Row(description='RESIST/OBSTRUCT/DISARM OFFICER'),
#  Row(description='POSS: PCP'),
#  Row(description='KIDNAPPING'),
#  Row(description='REGISTER OF SALES BY DEALER'),
#  Row(description='UNLAWFUL VISITATION INTERFERENCE'),
#  Row(description='CONTRIBUTE DELINQUENCY OF A CHILD'),
#  Row(description='ATTEMPT NON-AGGRAVATED'),
#  Row(description='ATTEMPT AGG: KNIFE/CUT INSTR'),
#  Row(description='OTHER PROSTITUTION OFFENSE'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY'),
#  Row(description='ATTEMPT AGGRAVATED'),
#  Row(description='POSSESS - HEROIN (BLACK TAR)'),
#  Row(description='AGGRAVATED PO: OTHER DANG WEAP'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: OTHER DANGEROUS WEAPON'),
#  Row(description='TO RESIDENCE'),
#  Row(description='SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR'),
#  Row(description='MANUFACTURE / DELIVER - SYNTHETIC MARIJUANA'),
#  Row(description='ATTEMPT STRONG ARM: NO WEAPON'),
#  Row(description='SEX OFFENDER: FAIL TO REGISTER'),
#  Row(description='GAME/AMUSEMENT DEVICE'),
#  Row(description='PAROLE VIOLATION'),
#  Row(description='VIOLENT OFFENDER - ANNUAL REGISTRATION'),
#  Row(description='THEFT OF LOST/MISLAID PROP'),
#  Row(description='FORCIBLE DETENTION'),
#  Row(description='AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL'),
#  Row(description='SIMPLE'),
#  Row(description='HARBOR RUNAWAY'),
#  Row(description='CYCLE, SCOOTER, BIKE NO VIN'),
#  Row(description='PROTECTED EMPLOYEE: HANDS NO / MIN INJURY'),
#  Row(description='SELL / GIVE / DELIVER LIQUOR TO MINOR'),
#  Row(description='VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE'),
#  Row(description='POSS: CANNABIS 30GMS OR LESS'),
#  Row(description='POSS: BARBITUATES'),
#  Row(description='INTIMIDATION OF LAW ENFORCEMENT OFFICIAL'),
#  Row(description='HOME INVASION'),
#  Row(description='CHILD ABDUCTION / STRANGER')]

# %%
unique_descriptions.sort(key=lambda x: x.description)

# %%
unique_descriptions
# Out:
# [Row(description='$300 AND UNDER'),
#  Row(description='$500 AND UNDER'),
#  Row(description='ABUSE / NEGLECT - CARE FACILITY'),
#  Row(description='ABUSE/NEGLECT: CARE FACILITY'),
#  Row(description='ADULTRY'),
#  Row(description='AGG CRIM SEX ABUSE FAM MEMBER'),
#  Row(description='AGG CRIMINAL SEXUAL ABUSE'),
#  Row(description='AGG PO HANDS ETC SERIOUS INJ'),
#  Row(description='AGG PO HANDS NO/MIN INJURY'),
#  Row(description='AGG PRO EMP HANDS SERIOUS INJ'),
#  Row(description='AGG PRO.EMP: HANDGUN'),
#  Row(description='AGG PRO.EMP: OTHER DANG WEAPON'),
#  Row(description='AGG PRO.EMP: OTHER FIREARM'),
#  Row(description='AGG PRO.EMP:KNIFE/CUTTING INST'),
#  Row(description='AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY'),
#  Row(description='AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY'),
#  Row(description='AGG RITUAL MUT:HANDGUN'),
#  Row(description='AGG RITUAL MUT:KNIFE/CUTTING I'),
#  Row(description='AGG RITUAL MUT:OTH DANG WEAPON'),
#  Row(description='AGG SEX ASSLT OF CHILD FAM MBR'),
#  Row(description='AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='AGG. PROTECTED EMPLOYEE - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='AGG: FINANCIAL ID THEFT'),
#  Row(description='AGG: HANDS/FIST/FEET NO/MINOR INJURY'),
#  Row(description='AGG: HANDS/FIST/FEET SERIOUS INJURY'),
#  Row(description='AGGRAVATED'),
#  Row(description='AGGRAVATED - HANDGUN'),
#  Row(description='AGGRAVATED - HANDS, FISTS, FEET, NO / MINOR INJURY'),
#  Row(description='AGGRAVATED - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='AGGRAVATED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='AGGRAVATED - OTHER'),
#  Row(description='AGGRAVATED - OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED - OTHER FIREARM'),
#  Row(description='AGGRAVATED COMPUTER TAMPERING'),
#  Row(description='AGGRAVATED CRIMINAL SEXUAL ABUSE'),
#  Row(description='AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - HANDGUN'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY - OTHER FIREARM'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: HANDGUN'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SERIOUS INJURY'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: KNIFE / CUTTING INSTSTRUMENT'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM'),
#  Row(description='AGGRAVATED FINANCIAL IDENTITY THEFT'),
#  Row(description='AGGRAVATED OF A CHILD'),
#  Row(description='AGGRAVATED OF A SENIOR CITIZEN'),
#  Row(description='AGGRAVATED OF A UNBORN CHILD'),
#  Row(description='AGGRAVATED OF AN UNBORN CHILD'),
#  Row(description='AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MINOR INJURY'),
#  Row(description='AGGRAVATED P.O. - HANDS, FISTS, FEET, SERIOUS INJURY'),
#  Row(description='AGGRAVATED PO: HANDGUN'),
#  Row(description='AGGRAVATED PO: KNIFE/CUT INSTR'),
#  Row(description='AGGRAVATED PO: OTHER DANG WEAP'),
#  Row(description='AGGRAVATED PO: OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED PO: OTHER FIREARM'),
#  Row(description='AGGRAVATED PO:KNIFE/CUT INSTR'),
#  Row(description='AGGRAVATED POLICE OFFICER - HANDGUN'),
#  Row(description='AGGRAVATED POLICE OFFICER - HANDS, FISTS, FEET, NO INJURY'),
#  Row(description='AGGRAVATED POLICE OFFICER - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='AGGRAVATED POLICE OFFICER - OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED POLICE OFFICER - OTHER FIREARM'),
#  Row(description='AGGRAVATED PROTECTED EMPLOYEE - HANDGUN'),
#  Row(description='AGGRAVATED PROTECTED EMPLOYEE - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='AGGRAVATED PROTECTED EMPLOYEE - OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'),
#  Row(description='AGGRAVATED VEHICULAR HIJACKING'),
#  Row(description='AGGRAVATED: HANDGUN'),
#  Row(description='AGGRAVATED: HANDS / FIST / FEET SERIOUS INJURY'),
#  Row(description='AGGRAVATED: KNIFE / CUTTING INSTRUMENT'),
#  Row(description='AGGRAVATED: KNIFE/CUT INSTR'),
#  Row(description='AGGRAVATED: OTHER'),
#  Row(description='AGGRAVATED: OTHER DANG WEAPON'),
#  Row(description='AGGRAVATED: OTHER DANGEROUS WEAPON'),
#  Row(description='AGGRAVATED: OTHER FIREARM'),
#  Row(description='AGGRAVATED:KNIFE/CUTTING INSTR'),
#  Row(description='AIDING ARRESTEE ESCAPE'),
#  Row(description='ALTER / FORGE PRESCRIPTION'),
#  Row(description='ALTER COINS'),
#  Row(description='ALTER/FORGE PRESCRIPTION'),
#  Row(description='ANIMAL ABUSE / NEGLECT'),
#  Row(description='ANIMAL ABUSE/NEGLECT'),
#  Row(description='ANIMAL FIGHTING'),
#  Row(description='ARMED - HANDGUN'),
#  Row(description='ARMED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='ARMED - OTHER DANGEROUS WEAPON'),
#  Row(description='ARMED - OTHER FIREARM'),
#  Row(description='ARMED VIOLENCE'),
#  Row(description='ARMED WHILE UNDER THE INFLUENCE'),
#  Row(description='ARMED: HANDGUN'),
#  Row(description='ARMED: OTHER DANGEROUS WEAPON'),
#  Row(description='ARMED: OTHER FIREARM'),
#  Row(description='ARMED:KNIFE/CUTTING INSTRUMENT'),
#  Row(description='ARSON THREAT'),
#  Row(description='ARSONIST - ANNUAL REGISTRATION'),
#  Row(description='ARSONIST - FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='ARSONIST: ANNUAL REGISTRATION'),
#  Row(description='ARSONIST: DUTY TO REGISTER'),
#  Row(description='ARSONIST: FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='ATT AGG CRIM SEXUAL ABUSE'),
#  Row(description='ATT AGG CRIMINAL SEXUAL ABUSE'),
#  Row(description='ATT CRIM SEXUAL ABUSE'),
#  Row(description='ATT: AUTOMOBILE'),
#  Row(description='ATT: TRUCK, BUS, MOTOR HOME'),
#  Row(description='ATTEMPT - AUTOMOBILE'),
#  Row(description='ATTEMPT - CYCLE, SCOOTER, BIKE WITH VIN'),
#  Row(description='ATTEMPT - FINANCIAL IDENTITY THEFT'),
#  Row(description='ATTEMPT - TRUCK, BUS, MOTOR HOME'),
#  Row(description='ATTEMPT AGG: HANDGUN'),
#  Row(description='ATTEMPT AGG: KNIFE/CUT INSTR'),
#  Row(description='ATTEMPT AGG: OTHER'),
#  Row(description='ATTEMPT AGG: OTHER DANG WEAPON'),
#  Row(description='ATTEMPT AGG: OTHER FIREARM'),
#  Row(description='ATTEMPT AGGRAVATED'),
#  Row(description='ATTEMPT AGGRAVATED - HANDGUN'),
#  Row(description='ATTEMPT AGGRAVATED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='ATTEMPT AGGRAVATED - OTHER'),
#  Row(description='ATTEMPT AGGRAVATED - OTHER DANGEROUS WEAPON'),
#  Row(description='ATTEMPT AGGRAVATED CRIMINAL SEXUAL ABUSE'),
#  Row(description='ATTEMPT ARMED - HANDGUN'),
#  Row(description='ATTEMPT ARMED - KNIFE / CUTTING INSTRUMENT'),
#  Row(description='ATTEMPT ARMED - OTHER DANGEROUS WEAPON'),
#  Row(description='ATTEMPT ARMED - OTHER FIREARM'),
#  Row(description='ATTEMPT ARMED: HANDGUN'),
#  Row(description='ATTEMPT ARSON'),
#  Row(description='ATTEMPT CRIMINAL SEXUAL ABUSE'),
#  Row(description='ATTEMPT FINANCIAL IDENTITY THEFT'),
#  Row(description='ATTEMPT FORCIBLE ENTRY'),
#  Row(description='ATTEMPT NON-AGGRAVATED'),
#  Row(description='ATTEMPT POSSESSION CANNABIS'),
#  Row(description='ATTEMPT POSSESSION NARCOTICS'),
#  Row(description='ATTEMPT STRONG ARM - NO WEAPON'),
#  Row(description='ATTEMPT STRONG ARM: NO WEAPON'),
#  Row(description='ATTEMPT THEFT'),
#  Row(description='ATTEMPT: AGGRAVATED'),
#  Row(description='ATTEMPT: ARMED-HANDGUN'),
#  Row(description='ATTEMPT: ARMED-KNIFE/CUT INSTR'),
#  Row(description='ATTEMPT: ARMED-OTHER DANG WEAP'),
#  Row(description='ATTEMPT: ARMED-OTHER FIREARM'),
#  Row(description='ATTEMPT: CYCLE, SCOOTER, BIKE NO VIN'),
#  Row(description='ATTEMPT: CYCLE, SCOOTER, BIKE W-VIN'),
#  Row(description='ATTEMPT: STRONGARM-NO WEAPON'),
#  Row(description='AUTOMOBILE'),
#  Row(description='BIGAMY'),
#  Row(description='BOARD PLANE WITH WEAPON'),
#  Row(description='BOGUS CHECK'),
#  Row(description='BOLITA OR BOLI PUL/OFFICE'),
#  Row(description='BOLITA OR BOLI PUL/RUNNER'),
#  Row(description='BOLITA OR BOLI PUL/WRITER'),
#  Row(description='BOMB THREAT'),
#  Row(description='BOOKMAKING/HORSES'),
#  Row(description='BOOKMAKING/SPORTS'),
#  Row(description='BRIBERY'),
#  Row(description='BY EXPLOSIVE'),
#  Row(description='BY FIRE'),
#  Row(description='CAB OPERATION'),
#  Row(description='CALCULATED CANNABIS CONSPIRACY'),
#  Row(description='CALL OPERATION'),
#  Row(description='CANNABIS PLANT'),
#  Row(description='CHILD ABANDONMENT'),
#  Row(description='CHILD ABDUCTION'),
#  Row(description='CHILD ABDUCTION / STRANGER'),
#  Row(description='CHILD ABDUCTION/STRANGER'),
#  Row(description='CHILD ABUSE'),
#  Row(description='CHILD PORNOGRAPHY'),
#  Row(description='COMMERCIAL SEX ACTS'),
#  Row(description='COMPELLING CONFESSION'),
#  Row(description='COMPELLING ORG MEMBERSHIP'),
#  Row(description='COMPOUNDING A CRIME'),
#  Row(description='COMPUTER FRAUD'),
#  Row(description='CONCEALED CARRY LICENSE REVOCATION'),
#  Row(description='CONCEALING/AIDING A FUGITIVE'),
#  Row(description='CONT SUBS:FAIL TO MAINT RECORD'),
#  Row(description='CONTRABAND IN PRISON'),
#  Row(description='CONTRIBUTE CRIM DELINQUENCY JUVENILE'),
#  Row(description='CONTRIBUTE DELINQUENCY OF A CHILD'),
#  Row(description='CONTRIBUTE TO THE CRIMINAL DELINQUENCY OF CHILD'),
#  Row(description='CONTRIBUTE TO THE DELINQUENCY OF CHILD'),
#  Row(description='COUNTERFEIT CHECK'),
#  Row(description='COUNTERFEITING DOCUMENT'),
#  Row(description='CREDIT CARD FRAUD'),
#  Row(description='CRIM SEX ABUSE BY FAM MEMBER'),
#  Row(description='CRIMINAL DEFACEMENT'),
#  Row(description='CRIMINAL DRUG CONSPIRACY'),
#  Row(description='CRIMINAL SEXUAL ABUSE'),
#  Row(description='CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER'),
#  Row(description='CRIMINAL TRANSMISSION OF HIV'),
#  Row(description='CYBERSTALKING'),
#  Row(description='CYCLE, SCOOTER, BIKE NO VIN'),
#  Row(description='CYCLE, SCOOTER, BIKE W-VIN'),
#  Row(description='CYCLE, SCOOTER, BIKE WITH VIN'),
#  Row(description='DECEPTIVE COLLECTION PRACTICES'),
#  Row(description='DEFACE IDENT MARKS OF FIREARM'),
#  Row(description='DEFACE IDENTIFICATION MARKS OF FIREARM'),
#  Row(description='DEL CONT SUBS TO PERSON <18'),
#  Row(description='DELIVER CANNABIS TO PERSON <18'),
#  Row(description='DELIVERY CONTAINER THEFT'),
#  Row(description='DISCLOSE DV VICTIM LOCATION'),
#  Row(description='DOMESTIC BATTERY SIMPLE'),
#  Row(description='DOMESTIC VIOLENCE'),
#  Row(description='EAVESDROPPING'),
#  Row(description='EDUCATIONAL INTIMIDAITON'),
#  Row(description='EMBEZZLEMENT'),
#  Row(description='EMPLOY MINOR'),
#  Row(description='ENDANGERING LIFE / HEALTH OF CHILD'),
#  Row(description='ENDANGERING LIFE/HEALTH CHILD'),
#  Row(description='ESCAPE'),
#  Row(description='EXTORTION'),
#  Row(description='FAIL REGISTER LIC:CONT SUBS'),
#  Row(description='FAILURE TO KEEP HYPO RECORDS'),
#  Row(description='FALSE / STOLEN / ALTERED TRP'),
#  Row(description='FALSE FIRE ALARM'),
#  Row(description='FALSE POLICE REPORT'),
#  Row(description='FALSE/STOLEN/ALTERED TRP'),
#  Row(description='FINAN EXPLOIT-ELDERLY/DISABLED'),
#  Row(description='FINANCIAL EXPLOITATION OF AN ELDERLY OR DISABLED PERSON'),
#  Row(description='FINANCIAL ID THEFT: OVER $300'),
#  Row(description='FINANCIAL ID THEFT:$300 &UNDER'),
#  Row(description='FINANCIAL IDENTITY THEFT $300 AND UNDER'),
#  Row(description='FINANCIAL IDENTITY THEFT OVER $ 300'),
#  Row(description='FINANCIAL IDENTITY THEFT: OVER $300'),
#  Row(description='FIREARM REGISTRATION VIOLATION'),
#  Row(description='FIRST DEGREE MURDER'),
#  Row(description='FOID - REVOCATION'),
#  Row(description='FORCIBLE DETENTION'),
#  Row(description='FORCIBLE ENTRY'),
#  Row(description='FORFEIT PROPERTY'),
#  Row(description='FORGERY'),
#  Row(description='FORNICATION'),
#  Row(description='FOUND PASSPORT'),
#  Row(description='FOUND SUSPECT NARCOTICS'),
#  Row(description='FRAUD OR CONFIDENCE GAME'),
#  Row(description='FROM BUILDING'),
#  Row(description='FROM COIN-OP MACHINE/DEVICE'),
#  Row(description='FROM COIN-OPERATED MACHINE OR DEVICE'),
#  Row(description='GAME / AMUSEMENT DEVICE'),
#  Row(description='GAME/AMUSEMENT DEVICE'),
#  Row(description='GAME/CARDS'),
#  Row(description='GAME/DICE'),
#  Row(description='GUN OFFENDER - ANNUAL REGISTRATION'),
#  Row(description='GUN OFFENDER - DUTY TO REGISTER'),
#  Row(description='GUN OFFENDER - DUTY TO REPORT CHANGE OF INFORMATION'),
#  Row(description='GUN OFFENDER NOTIFICATION-NO CONTACT'),
#  Row(description='GUN OFFENDER: ANNUAL REGISTRATION'),
#  Row(description='GUN OFFENDER: DUTY TO REGISTER'),
#  Row(description='GUN OFFENDER: DUTY TO REPORT CHANGE OF INFORMATION'),
#  Row(description='HARASSMENT BY ELECTRONIC MEANS'),
#  Row(description='HARASSMENT BY TELEPHONE'),
#  Row(description='HARBOR RUNAWAY'),
#  Row(description='HAZARDOUS MATERIALS VIOLATION'),
#  Row(description='HOME INVASION'),
#  Row(description='ILLEGAL CONSUMPTION BY MINOR'),
#  Row(description='ILLEGAL ILL LOTTERY'),
#  Row(description='ILLEGAL POSSESSION BY MINOR'),
#  Row(description='ILLEGAL POSSESSION CASH CARD'),
#  Row(description='ILLEGAL USE CASH CARD'),
#  Row(description='IMPERSONATION'),
#  Row(description='IN TAVERN'),
#  Row(description='INDECENT SOLICITATION OF A CHILD'),
#  Row(description='INDECENT SOLICITATION OF AN ADULT'),
#  Row(description='INDECENT SOLICITATION/ADULT'),
#  Row(description='INDECENT SOLICITATION/CHILD'),
#  Row(description='INSTITUTIONAL VANDALISM'),
#  Row(description='INSURANCE FRAUD'),
#  Row(description='INTERFERE W/ EMERGENCY EQUIP'),
#  Row(description='INTERFERE W/ HIGHER EDUCATION'),
#  Row(description='INTERFERE WITH EMERGENCY EQUIPMENT'),
#  Row(description='INTERFERENCE JUDICIAL PROCESS'),
#  Row(description='INTIMIDATION'),
#  Row(description='INTIMIDATION OF LAW ENFORCEMENT OFFICIAL'),
#  Row(description='INTOXICATING COMPOUNDS'),
#  Row(description='INVOLUNTARY MANSLAUGHTER'),
#  Row(description='INVOLUNTARY SERVITUDE'),
#  Row(description='JUVENILE PIMPING'),
#  Row(description='KEEP PLACE OF JUV PROSTITUTION'),
#  Row(description='KEEP PLACE OF PROSTITUTION'),
#  Row(description='KIDNAPPING'),
#  Row(description='LIBRARY THEFT'),
#  Row(description='LIBRARY VANDALISM'),
#  Row(description='LICENSE VIOLATION'),
#  Row(description='LICENSED PREMISE'),
#  Row(description='LIQUOR LICENSE VIOLATION'),
#  Row(description='LOOTING'),
#  Row(description='LOST PASSPORT'),
#  Row(description='LOTTERY/OTHER'),
#  Row(description='LOTTERY/PARI-MUTUEL'),
#  Row(description='LOTTERY/PARLAY CARDS'),
#  Row(description='MANU/DEL:CANNABIS 10GM OR LESS'),
#  Row(description='MANU/DEL:CANNABIS OVER 10 GMS'),
#  Row(description='MANU/DELIVER: HALLUCINOGEN'),
#  Row(description='MANU/DELIVER: HEROIN (WHITE)'),
#  Row(description='MANU/DELIVER: HEROIN(BRN/TAN)'),
#  Row(description='MANU/DELIVER: METHAMPHETAMINES'),
#  Row(description='MANU/DELIVER:AMPHETAMINES'),
#  Row(description='MANU/DELIVER:BARBITUATES'),
#  Row(description='MANU/DELIVER:COCAINE'),
#  Row(description='MANU/DELIVER:CRACK'),
#  Row(description='MANU/DELIVER:HEROIN(BLACK TAR)'),
#  Row(description='MANU/DELIVER:LOOK-ALIKE DRUG'),
#  Row(description='MANU/DELIVER:PCP'),
#  Row(description='MANU/DELIVER:SYNTHETIC DRUGS'),
#  Row(description='MANU/POSS. W/INTENT TO DELIVER: SYNTHETIC MARIJUANA'),
#  Row(description='MANUFACTURE / DELIVER -  HEROIN (WHITE)'),
#  Row(description='MANUFACTURE / DELIVER - AMPHETAMINES'),
#  Row(description='MANUFACTURE / DELIVER - BARBITURATES'),
#  Row(description='MANUFACTURE / DELIVER - CANNABIS 10 GRAMS OR LESS'),
#  Row(description='MANUFACTURE / DELIVER - CANNABIS OVER 10 GRAMS'),
#  Row(description='MANUFACTURE / DELIVER - COCAINE'),
#  Row(description='MANUFACTURE / DELIVER - CRACK'),
#  Row(description='MANUFACTURE / DELIVER - HALLUCINOGEN'),
#  Row(description='MANUFACTURE / DELIVER - HEROIN (TAN / BROWN TAR)'),
#  Row(description='MANUFACTURE / DELIVER - METHAMPHETAMINE'),
#  Row(description='MANUFACTURE / DELIVER - PCP'),
#  Row(description='MANUFACTURE / DELIVER - SYNTHETIC DRUGS'),
#  Row(description='MANUFACTURE / DELIVER - SYNTHETIC MARIJUANA'),
#  Row(description='MARRYING A BIGAMIST'),
#  Row(description='MINOR MISREPRESENT AGE'),
#  Row(description='MOB ACTION'),
#  Row(description='MONEY LAUNDERING'),
#  Row(description='NATIONAL LOTTERY'),
#  Row(description='NON-AGGRAVATED'),
#  Row(description='NON-CONSENSUAL DISSEMINATION OF PRIVATE SEXUAL IMAGES'),
#  Row(description='NON-CONSENSUAL DISSEMINATION PRIVATE SEXUAL IMAGES'),
#  Row(description='NOTIFICATION OF CIVIL NO CONTACT ORDER'),
#  Row(description='NOTIFICATION OF STALKING - NO CONTACT ORDER'),
#  Row(description='OBSCENE MATTER'),
#  Row(description='OBSCENE TELEPHONE CALLS'),
#  Row(description='OBSCENITY'),
#  Row(description='OBSTRUCTING IDENTIFICATION'),
#  Row(description='OBSTRUCTING JUSTICE'),
#  Row(description='OBSTRUCTING SERVICE'),
#  Row(description='OF AN UNBORN CHILD'),
#  Row(description='OF UNBORN CHILD'),
#  Row(description='OFFICIAL MISCONDUCT'),
#  Row(description='OTHER'),
#  Row(description='OTHER ARSON / EXPLOSIVE INCIDENT'),
#  Row(description='OTHER ARSON/EXPLOSIVE INCIDENT'),
#  Row(description='OTHER CRIME AGAINST PERSON'),
#  Row(description='OTHER CRIME INVOLVING PROPERTY'),
#  Row(description='OTHER OFFENSE'),
#  Row(description='OTHER PROSTITUTION OFFENSE'),
#  Row(description='OTHER VEHICLE OFFENSE'),
#  Row(description='OTHER VIOLATION'),
#  Row(description='OTHER WEAPONS VIOLATION'),
#  Row(description='OVER $300'),
#  Row(description='OVER $500'),
#  Row(description='PANDERING'),
#  Row(description='PAROLE VIOLATION'),
#  Row(description='PATRONIZE JUVENILE PROSTITUTE'),
#  Row(description='PATRONIZING A PROSTITUTE'),
#  Row(description='PAY TV SERVICE OFFENSES'),
#  Row(description='PEEPING TOM'),
#  Row(description='PIMPING'),
#  Row(description='POCKET-PICKING'),
#  Row(description='POLICY/OTHER'),
#  Row(description='POS: CHEMICAL/DRY-ICE DEVICE'),
#  Row(description='POS: EXPLOSIVE/INCENDIARY DEV'),
#  Row(description='POS: HYPODERMIC NEEDLE'),
#  Row(description='POS: PORNOGRAPHIC PRINT'),
#  Row(description='POSS FIREARM/AMMO:NO FOID CARD'),
#  Row(description='POSS. KEYS OR DEV.TO COIN MACH'),
#  Row(description='POSS: AMPHETAMINES'),
#  Row(description='POSS: BARBITUATES'),
#  Row(description='POSS: CANNABIS 30GMS OR LESS'),
#  Row(description='POSS: CANNABIS MORE THAN 30GMS'),
#  Row(description='POSS: COCAINE'),
#  Row(description='POSS: CRACK'),
#  Row(description='POSS: HALLUCINOGENS'),
#  Row(description='POSS: HEROIN(BLACK TAR)'),
#  Row(description='POSS: HEROIN(BRN/TAN)'),
#  Row(description='POSS: HEROIN(WHITE)'),
#  Row(description='POSS: LOOK-ALIKE DRUGS'),
#  Row(description='POSS: METHAMPHETAMINES'),
#  Row(description='POSS: PCP'),
#  Row(description='POSS: SYNTHETIC DRUGS'),
#  Row(description='POSSESS - AMPHETAMINES'),
#  Row(description='POSSESS - BARBITURATES'),
#  Row(description='POSSESS - CANNABIS 30 GRAMS OR LESS'),
#  Row(description='POSSESS - CANNABIS MORE THAN 30 GRAMS'),
#  Row(description='POSSESS - COCAINE'),
#  Row(description='POSSESS - CRACK'),
#  Row(description='POSSESS - HALLUCINOGENS'),
#  Row(description='POSSESS - HEROIN (BLACK TAR)'),
#  Row(description='POSSESS - HEROIN (TAN / BROWN TAR)'),
#  Row(description='POSSESS - HEROIN (WHITE)'),
#  Row(description='POSSESS - METHAMPHETAMINE'),
#  Row(description='POSSESS - PCP'),
#  Row(description='POSSESS - SYNTHETIC DRUGS'),
#  Row(description='POSSESS FIREARM / AMMUNITION - NO FOID CARD'),
#  Row(description='POSSESSION - EXPLOSIVE / INCENDIARY DEVICE'),
#  Row(description='POSSESSION OF BURGLARY TOOLS'),
#  Row(description='POSSESSION OF DRUG EQUIPMENT'),
#  Row(description='POSSESSION OF PORNOGRAPHIC PRINT'),
#  Row(description='POSSESSION: SYNTHETIC MARIJUANA'),
#  Row(description='PREDATORY'),
#  Row(description='PRO EMP HANDS NO/MIN INJURY'),
#  Row(description='PROBATION VIOLATION'),
#  Row(description='PROHIBITED PLACES'),
#  Row(description='PROTECTED EMPLOYEE - HANDS, FISTS, FEET, NO / MINOR INJURY'),
#  Row(description='PROTECTED EMPLOYEE: HANDS NO / MIN INJURY'),
#  Row(description='PUBLIC DEMONSTRATION'),
#  Row(description='PUBLIC INDECENCY'),
#  Row(description='PURSE-SNATCHING'),
#  Row(description='RECKLESS CONDUCT'),
#  Row(description='RECKLESS FIREARM DISCHARGE'),
#  Row(description='RECKLESS HOMICIDE'),
#  Row(description='REFUSING TO AID AN OFFICER'),
#  Row(description='REGISTER FED GAMBLING STAMP'),
#  Row(description='REGISTER OF SALES BY DEALER'),
#  Row(description='RESIST / OBSTRUCT / DISARM OFFICER'),
#  Row(description='RESIST/OBSTRUCT/DISARM OFFICER'),
#  Row(description='RETAIL THEFT'),
#  Row(description='SALE / DELIVER - DRUG PARAPHERNALIA'),
#  Row(description='SALE / DISTRIBUTE OBSCENE MATERIAL TO MINOR'),
#  Row(description='SALE TOBACCO PRODUCTS TO MINOR'),
#  Row(description='SALE/DEL DRUG PARAPHERNALIA'),
#  Row(description='SALE/DEL HYPODERMIC NEEDLE'),
#  Row(description='SALE/DIST OBSCENE MAT TO MINOR'),
#  Row(description='SELL / GIVE / DELIVER LIQUOR TO MINOR'),
#  Row(description='SELL/ADVERTISE FIREWORKS'),
#  Row(description='SELL/GIVE/DEL LIQUOR TO MINOR'),
#  Row(description='SEX ASSLT OF CHILD BY FAM MBR'),
#  Row(description='SEX OFFENDER - FAIL TO REGISTER'),
#  Row(description='SEX OFFENDER - FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='SEX OFFENDER: FAIL REG NEW ADD'),
#  Row(description='SEX OFFENDER: FAIL TO REGISTER'),
#  Row(description='SEX OFFENDER: PROHIBITED ZONE'),
#  Row(description='SEX RELATION IN FAMILY'),
#  Row(description='SEXUAL ASSAULT OF CHILD BY FAMILY MEMBER'),
#  Row(description='SEXUAL EXPLOITATION OF A CHILD'),
#  Row(description='SEXUAL RELATIONS IN FAMILY'),
#  Row(description='SIMPLE'),
#  Row(description='SOLICIT FOR BUSINESS'),
#  Row(description='SOLICIT FOR PROSTITUTE'),
#  Row(description='SOLICIT NARCOTICS ON PUBLIC WAY'),
#  Row(description='SOLICIT NARCOTICS ON PUBLICWAY'),
#  Row(description='SOLICIT OFF PUBLIC WAY'),
#  Row(description='SOLICIT ON PUBLIC WAY'),
#  Row(description='SOLICITING FOR A PROSTITUTE'),
#  Row(description='SOLICITING FOR BUSINESS'),
#  Row(description='SPORTS TAMPERING'),
#  Row(description='STOLEN PROP: BUY/RECEIVE/POS.'),
#  Row(description='STOLEN PROPERTY BUY / RECEIVE / POSSESS'),
#  Row(description='STRONG ARM - NO WEAPON'),
#  Row(description='STRONGARM - NO WEAPON'),
#  Row(description='STRONGARM: NO WEAPON'),
#  Row(description='TAMPER WITH MOTOR VEHICLE'),
#  Row(description='TELEPHONE THREAT'),
#  Row(description='THEFT / RECOVERY - AUTOMOBILE'),
#  Row(description='THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN'),
#  Row(description='THEFT / RECOVERY - TRUCK, BUS, MOBILE HOME'),
#  Row(description='THEFT BY LESSEE, MOTOR VEHICLE'),
#  Row(description='THEFT BY LESSEE, NON-MOTOR VEHICLE'),
#  Row(description='THEFT BY LESSEE,MOTOR VEH'),
#  Row(description='THEFT BY LESSEE,NON-VEH'),
#  Row(description='THEFT OF LABOR / SERVICES'),
#  Row(description='THEFT OF LABOR/SERVICES'),
#  Row(description='THEFT OF LOST / MISLAID PROPERTY'),
#  Row(description='THEFT OF LOST/MISLAID PROP'),
#  Row(description='THEFT RETAIL'),
#  Row(description='THEFT/RECOVERY: AUTOMOBILE'),
#  Row(description='THEFT/RECOVERY: CYCLE, SCOOTER, BIKE NO VIN'),
#  Row(description='THEFT/RECOVERY: CYCLE, SCOOTER, BIKE W-VIN'),
#  Row(description='THEFT/RECOVERY: TRUCK,BUS,MHOME'),
#  Row(description='TO AIRPORT'),
#  Row(description='TO CITY OF CHICAGO PROPERTY'),
#  Row(description='TO FIRE FIGHT.APP.EQUIP'),
#  Row(description='TO LAND'),
#  Row(description='TO PROPERTY'),
#  Row(description='TO RESIDENCE'),
#  Row(description='TO STATE SUP LAND'),
#  Row(description='TO STATE SUP PROP'),
#  Row(description='TO STATE SUPPORTED PROPERTY'),
#  Row(description='TO VEHICLE'),
#  Row(description='TRUCK, BUS, MOTOR HOME'),
#  Row(description='UNAUTHORIZED VIDEOTAPING'),
#  Row(description='UNIDENTIFIABLE RECORDING SOUND'),
#  Row(description='UNLAWFUL ENTRY'),
#  Row(description='UNLAWFUL INTERFERE/VISITATION'),
#  Row(description='UNLAWFUL POSS AMMUNITION'),
#  Row(description='UNLAWFUL POSS OF HANDGUN'),
#  Row(description='UNLAWFUL POSS OTHER FIREARM'),
#  Row(description='UNLAWFUL POSSESSION - AMMUNITION'),
#  Row(description='UNLAWFUL POSSESSION - HANDGUN'),
#  Row(description='UNLAWFUL POSSESSION - OTHER FIREARM'),
#  Row(description='UNLAWFUL RESTRAINT'),
#  Row(description='UNLAWFUL SALE - DELIVERY OF FIREARM AT SCHOOL'),
#  Row(description='UNLAWFUL SALE - HANDGUN'),
#  Row(description='UNLAWFUL SALE HANDGUN'),
#  Row(description='UNLAWFUL SALE OTHER FIREARM'),
#  Row(description='UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL'),
#  Row(description='UNLAWFUL USE - HANDGUN'),
#  Row(description='UNLAWFUL USE - OTHER DANGEROUS WEAPON'),
#  Row(description='UNLAWFUL USE - OTHER FIREARM'),
#  Row(description='UNLAWFUL USE / SALE OF AIR RIFLE'),
#  Row(description='UNLAWFUL USE HANDGUN'),
#  Row(description='UNLAWFUL USE OF A COMPUTER'),
#  Row(description='UNLAWFUL USE OF BODY ARMOR'),
#  Row(description='UNLAWFUL USE OF RECORDED SOUND'),
#  Row(description='UNLAWFUL USE OTHER DANG WEAPON'),
#  Row(description='UNLAWFUL USE OTHER FIREARM'),
#  Row(description='UNLAWFUL USE/SALE AIR RIFLE'),
#  Row(description='UNLAWFUL VISITATION INTERFERENCE'),
#  Row(description='USE OF METAL PIERCING BULLETS'),
#  Row(description='VEHICLE TITLE / REGISTRATION OFFENSE'),
#  Row(description='VEHICLE TITLE/REG OFFENSE'),
#  Row(description='VEHICULAR HIJACKING'),
#  Row(description='VIO BAIL BOND: DOM VIOLENCE'),
#  Row(description='VIOL CHARITABLE GAME ACT'),
#  Row(description='VIOLATE ORDER OF PROTECTION'),
#  Row(description='VIOLATION GPS MONITORING DEVICE'),
#  Row(description='VIOLATION OF BAIL BOND - DOMESTIC VIOLENCE'),
#  Row(description='VIOLATION OF CIVIL NO CONTACT ORDER'),
#  Row(description='VIOLATION OF SMOKING BAN'),
#  Row(description='VIOLATION OF STALKING NO CONTACT ORDER'),
#  Row(description='VIOLATION OF SUMMARY CLOSURE'),
#  Row(description='VIOLENT OFFENDER - ANNUAL REGISTRATION'),
#  Row(description='VIOLENT OFFENDER - DUTY TO REGISTER'),
#  Row(description='VIOLENT OFFENDER - FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='VIOLENT OFFENDER: ANNUAL REGISTRATION'),
#  Row(description='VIOLENT OFFENDER: DUTY TO REGISTER'),
#  Row(description='VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS'),
#  Row(description='WIREROOM/HORSES'),
#  Row(description='WIREROOM/SPORTS')]

# %%
#schema for dataframe
schema = StructType([
  StructField('id', IntegerType()),
  StructField('description', StringType())
  ])

# %%
#create for each unique descriptions an unique int and put it on a list
description_codes = []
df_description = spark.createDataFrame(spark.sparkContext.emptyRDD(),schema)

for i in unique_descriptions:
    if i.description != None:
        description_codes.append(i.description)
        index = description_codes.index(i.description)
        df_temp = spark.createDataFrame([(index, i.description)],("id", "description"))
        df_description = df_description.union(df_temp)

# %%
df_description.show(5)
# Out:
# +---+--------------------+
# | id|         description|
# +---+--------------------+
# |  0|      $300 AND UNDER|
# |  1|      $500 AND UNDER|
# |  2|ABUSE / NEGLECT -...|
# |  3|ABUSE/NEGLECT: CA...|
# |  4|             ADULTRY|
# +---+--------------------+
# only showing top 5 rows

# %%
collection_description.drop()

# %%
#write the infos into the mongo db
df_description.write.format("mongo").option("uri","mongodb://mongo:27017/mydb.description").mode("append").save()

# %%
#test = spark.read.format("mongo").option("uri","mongodb://mongo:27017/mydb.description").load()
#test.show(20)

# %%
# convert the string description into integer
myfunc =  UserDefinedFunction(lambda x: description_codes.index(x) if x in description_codes else -1)
df = df.withColumn('description_int', myfunc(col('description')))

# %%
df.show(10)
# Out:
# +------+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+------------+--------------------+-------------+--------------------+--------------------+----+----+---------------+
# |arrest|               block|case_number|community_area|                date|         description|district|domestic|    latitude|location_description|    longitude|        primary_type|          updated_on|ward|year|description_int|
# +------+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+------------+--------------------+-------------+--------------------+--------------------+----+----+---------------+
# | false| 050XX N ASHLAND AVE|   JB152500|             3|2001-01-01T00:00:...|AGG SEX ASSLT OF ...|     020|   false|        null|           RESIDENCE|         null|OFFENSE INVOLVING...|2018-10-27T16:00:...|  47|2001|             19|
# | false|   018XX N TALMAN AV|    G055473|          null|2001-01-01T00:00:...|      $500 AND UNDER|     014|   false|41.914955409|              STREET|-87.693605188|               THEFT|2015-08-17T15:03:...|null|2001|              1|
# | false|    034XX W ADAMS ST|    G057402|          null|2001-01-01T00:00:...|   CREDIT CARD FRAUD|     011|   false| 41.87821192|           RESIDENCE|-87.711432075|  DECEPTIVE PRACTICE|2015-08-17T15:03:...|null|2001|            184|
# | false|  062XX N PULASKI RD|    G061760|          null|2001-01-01T00:00:...|   CREDIT CARD FRAUD|     017|   false|41.995267432|  SMALL RETAIL STORE|-87.729044138|  DECEPTIVE PRACTICE|2015-08-17T15:03:...|null|2001|            184|
# | false|012XX N SPRINGFIE...|    G067736|          null|2001-01-01T00:00:...|              SIMPLE|     025|   false|41.903597909|           RESIDENCE|-87.724042825|             ASSAULT|2015-08-17T15:03:...|null|2001|            435|
# | false|045XX N CLARENDON AV|    G000065|          null|2001-01-01T00:00:...|          TO VEHICLE|     019|   false|41.963705611|              STREET|-87.650116531|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            477|
# | false|  026XX S INDIANA AV|    G000355|          null|2001-01-01T00:00:...|         TO PROPERTY|     002|   false|41.844745115|           APARTMENT|-87.621968071|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            472|
# | false|       036XX W 80 ST|    G000610|          null|2001-01-01T00:00:...|          TO VEHICLE|     008|   false|41.747712773|              STREET|-87.712370684|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            477|
# | false| 109XX S LONGWOOD DR|    G000070|          null|2001-01-01T00:00:...|         TO PROPERTY|     022|   false|41.694977232|           APARTMENT|-87.671447845|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            472|
# | false| 0000X W ILLINOIS ST|    G000802|          null|2001-01-01T00:00:...|          TO VEHICLE|     018|   false|41.890741624|PARKING LOT/GARAG...|-87.628671125|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            477|
# +------+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+------------+--------------------+-------------+--------------------+--------------------+----+----+---------------+
# only showing top 10 rows

# %% [markdown]
# Convert the Primary Type

# %%
#select unique primary_type
unique_primary_type = df.select("primary_type").distinct().collect()

# %%
unique_primary_type.sort(key=lambda x: x.primary_type)

# %%
#schema for dataframe
schema = StructType([
  StructField('id', IntegerType()),
  StructField('primary_type', StringType())
  ])

# %%
#create for each unique primary type an unique int and put it on a list
primary_type_code = []
df_primary_type = spark.createDataFrame(spark.sparkContext.emptyRDD(),schema)

for i in unique_primary_type:
    if i.primary_type != None:
        primary_type_code.append(i.primary_type)
        index = primary_type_code.index(i.primary_type)
        df_temp = spark.createDataFrame([(index, i.primary_type)],("id", "primary_type"))
        df_primary_type = df_primary_type.union(df_temp)

# %%
collection_primary_type.drop()

# %%
#write the infos into the mongo db
df_primary_type.write.format("mongo").option("uri","mongodb://mongo:27017/mydb.primary_type").mode("append").save()

# %%
#test = spark.read.format("mongo").option("uri","mongodb://mongo:27017/mydb.primary_type").load()
#test.show(10)

# %%
# convert the string primary type into integer
myfunc =  UserDefinedFunction(lambda x: primary_type_code.index(x) if x in primary_type_code else -1)
df = df.withColumn('primary_type_int', myfunc(col('primary_type')))

# %% [markdown]
# Convert the Location description

# %%
#select unique location description
unique_location_description = df.select("location_description").distinct().collect()

# %%
unique_location_description
# Out:
# [Row(location_description='RAILROAD PROPERTY'),
#  Row(location_description='SCHOOL - PRIVATE GROUNDS'),
#  Row(location_description='VEHICLE - COMMERCIAL'),
#  Row(location_description='AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA'),
#  Row(location_description='POLICE FACILITY/VEH PARKING LOT'),
#  Row(location_description='RESIDENCE - YARD (FRONT / BACK)'),
#  Row(location_description='MOTEL'),
#  Row(location_description='CHA PARKING LOT / GROUNDS'),
#  Row(location_description='SIDEWALK'),
#  Row(location_description='AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA'),
#  Row(location_description='OTHER RAILROAD PROPERTY / TRAIN DEPOT'),
#  Row(location_description='CTA GARAGE / OTHER PROPERTY'),
#  Row(location_description='CAR WASH'),
#  Row(location_description='TRUCKING TERMINAL'),
#  Row(location_description='AIRPORT/AIRCRAFT'),
#  Row(location_description='HOSPITAL'),
#  Row(location_description='MEDICAL/DENTAL OFFICE'),
#  Row(location_description='FEDERAL BUILDING'),
#  Row(location_description='TRAILER'),
#  Row(location_description='SCHOOL, PUBLIC, GROUNDS'),
#  Row(location_description='CTA STATION'),
#  Row(location_description='SPORTS ARENA/STADIUM'),
#  Row(location_description='FARM'),
#  Row(location_description='CEMETARY'),
#  Row(location_description='HOUSE'),
#  Row(location_description='VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER, LYFT)'),
#  Row(location_description='ROOMING HOUSE'),
#  Row(location_description='VACANT LOT'),
#  Row(location_description='SCHOOL, PRIVATE, BUILDING'),
#  Row(location_description='TAVERN / LIQUOR STORE'),
#  Row(location_description='PARKING LOT / GARAGE (NON RESIDENTIAL)'),
#  Row(location_description='DRIVEWAY'),
#  Row(location_description='VEHICLE-COMMERCIAL'),
#  Row(location_description='RESIDENCE - PORCH / HALLWAY'),
#  Row(location_description='COUNTY JAIL'),
#  Row(location_description='WAREHOUSE'),
#  Row(location_description='APPLIANCE STORE'),
#  Row(location_description='AIRPORT EXTERIOR - NON-SECURE AREA'),
#  Row(location_description='AIRPORT TERMINAL UPPER LEVEL - SECURE AREA'),
#  Row(location_description='VEHICLE - OTHER RIDE SERVICE'),
#  Row(location_description='DUMPSTER'),
#  Row(location_description='COIN OPERATED MACHINE'),
#  Row(location_description='CTA PLATFORM'),
#  Row(location_description='BARBER SHOP/BEAUTY SALON'),
#  Row(location_description='CLUB'),
#  Row(location_description=None),
#  Row(location_description='GANGWAY'),
#  Row(location_description='CTA "L" PLATFORM'),
#  Row(location_description='BANK'),
#  Row(location_description='FACTORY/MANUFACTURING BUILDING'),
#  Row(location_description='GROCERY FOOD STORE'),
#  Row(location_description='BRIDGE'),
#  Row(location_description='CHA GROUNDS'),
#  Row(location_description='MEDICAL / DENTAL OFFICE'),
#  Row(location_description='RESIDENCE-GARAGE'),
#  Row(location_description='CHA STAIRWELL'),
#  Row(location_description='CONVENIENCE STORE'),
#  Row(location_description='KENNEL'),
#  Row(location_description='LAKEFRONT/WATERFRONT/RIVERBANK'),
#  Row(location_description='PUBLIC HIGH SCHOOL'),
#  Row(location_description='ATM (AUTOMATIC TELLER MACHINE)'),
#  Row(location_description='BASEMENT'),
#  Row(location_description='GOVERNMENT BUILDING / PROPERTY'),
#  Row(location_description='AUTO'),
#  Row(location_description='AIRCRAFT'),
#  Row(location_description='SCHOOL - PRIVATE BUILDING'),
#  Row(location_description='HOTEL'),
#  Row(location_description='CHA HALLWAY/STAIRWELL/ELEVATOR'),
#  Row(location_description='TAXI CAB'),
#  Row(location_description='STREET'),
#  Row(location_description='DRIVEWAY - RESIDENTIAL'),
#  Row(location_description='CHURCH'),
#  Row(location_description='LAKE'),
#  Row(location_description='RIVER'),
#  Row(location_description='BARBERSHOP'),
#  Row(location_description='SCHOOL YARD'),
#  Row(location_description='NURSING / RETIREMENT HOME'),
#  Row(location_description='ATHLETIC CLUB'),
#  Row(location_description='GARAGE/AUTO REPAIR'),
#  Row(location_description='FACTORY / MANUFACTURING BUILDING'),
#  Row(location_description='OTHER COMMERCIAL TRANSPORTATION'),
#  Row(location_description='OTHER (SPECIFY)'),
#  Row(location_description='VEHICLE-COMMERCIAL - TROLLEY BUS'),
#  Row(location_description='TRUCK'),
#  Row(location_description='CHA ELEVATOR'),
#  Row(location_description='RESIDENCE - GARAGE'),
#  Row(location_description='MOVIE HOUSE / THEATER'),
#  Row(location_description='COMMERCIAL / BUSINESS OFFICE'),
#  Row(location_description='LIBRARY'),
#  Row(location_description='LIVERY AUTO'),
#  Row(location_description='RIVER BANK'),
#  Row(location_description='CTA BUS'),
#  Row(location_description='SCHOOL - PUBLIC GROUNDS'),
#  Row(location_description='CTA BUS STOP'),
#  Row(location_description='BOAT / WATERCRAFT'),
#  Row(location_description='COLLEGE / UNIVERSITY - RESIDENCE HALL'),
#  Row(location_description='LAUNDRY ROOM'),
#  Row(location_description='SCHOOL, PUBLIC, BUILDING'),
#  Row(location_description='GAS STATION DRIVE/PROP.'),
#  Row(location_description='CREDIT UNION'),
#  Row(location_description='HORSE STABLE'),
#  Row(location_description='BANQUET HALL'),
#  Row(location_description='GOVERNMENT BUILDING'),
#  Row(location_description='NURSING HOME'),
#  Row(location_description='GAS STATION'),
#  Row(location_description='CHA HALLWAY'),
#  Row(location_description='VEHICLE NON-COMMERCIAL'),
#  Row(location_description='SMALL RETAIL STORE'),
#  Row(location_description='CHA APARTMENT'),
#  Row(location_description='CHA HALLWAY / STAIRWELL / ELEVATOR'),
#  Row(location_description='HOTEL / MOTEL'),
#  Row(location_description='ABANDONED BUILDING'),
#  Row(location_description='TAVERN/LIQUOR STORE'),
#  Row(location_description='CLEANERS/LAUNDROMAT'),
#  Row(location_description='YARD'),
#  Row(location_description='CHA LOBBY'),
#  Row(location_description='RESIDENCE'),
#  Row(location_description='CHA PLAY LOT'),
#  Row(location_description='CTA PARKING LOT / GARAGE / OTHER PROPERTY'),
#  Row(location_description='BOAT/WATERCRAFT'),
#  Row(location_description='PAWN SHOP'),
#  Row(location_description='VEHICLE - OTHER RIDE SHARE SERVICE (LYFT, UBER, ETC.)'),
#  Row(location_description='POOL ROOM'),
#  Row(location_description='OFFICE'),
#  Row(location_description='AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA'),
#  Row(location_description='STAIRWELL'),
#  Row(location_description='SCHOOL, PRIVATE, GROUNDS'),
#  Row(location_description='AIRPORT VENDING ESTABLISHMENT'),
#  Row(location_description='DRUG STORE'),
#  Row(location_description='VEHICLE - COMMERCIAL: ENTERTAINMENT / PARTY BUS'),
#  Row(location_description='DEPARTMENT STORE'),
#  Row(location_description='VACANT LOT/LAND'),
#  Row(location_description='HOSPITAL BUILDING/GROUNDS'),
#  Row(location_description='CURRENCY EXCHANGE'),
#  Row(location_description='CHA BREEZEWAY'),
#  Row(location_description='CHURCH PROPERTY'),
#  Row(location_description='ALLEY'),
#  Row(location_description='AIRPORT BUILDING NON-TERMINAL - SECURE AREA'),
#  Row(location_description='PARKING LOT'),
#  Row(location_description='PARK PROPERTY'),
#  Row(location_description='RESIDENCE PORCH/HALLWAY'),
#  Row(location_description='CLEANING STORE'),
#  Row(location_description='AIRPORT TRANSPORTATION SYSTEM (ATS)'),
#  Row(location_description='RESTAURANT'),
#  Row(location_description='FOREST PRESERVE'),
#  Row(location_description='RESIDENTIAL YARD (FRONT/BACK)'),
#  Row(location_description='NEWSSTAND'),
#  Row(location_description='APARTMENT'),
#  Row(location_description='OTHER'),
#  Row(location_description='DAY CARE CENTER'),
#  Row(location_description='TAVERN'),
#  Row(location_description='RETAIL STORE'),
#  Row(location_description='CHURCH / SYNAGOGUE / PLACE OF WORSHIP'),
#  Row(location_description='LAGOON'),
#  Row(location_description='CTA TRAIN'),
#  Row(location_description='HALLWAY'),
#  Row(location_description='AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA'),
#  Row(location_description='HOTEL/MOTEL'),
#  Row(location_description='PORCH'),
#  Row(location_description='ANIMAL HOSPITAL'),
#  Row(location_description='GOVERNMENT BUILDING/PROPERTY'),
#  Row(location_description='COLLEGE / UNIVERSITY - GROUNDS'),
#  Row(location_description='POLICE FACILITY / VEHICLE PARKING LOT'),
#  Row(location_description='LAKEFRONT / WATERFRONT / RIVERBANK'),
#  Row(location_description='LIQUOR STORE'),
#  Row(location_description='VEHICLE-COMMERCIAL - ENTERTAINMENT/PARTY BUS'),
#  Row(location_description='FUNERAL PARLOR'),
#  Row(location_description='TAXICAB'),
#  Row(location_description='MOVIE HOUSE/THEATER'),
#  Row(location_description='OTHER RAILROAD PROP / TRAIN DEPOT'),
#  Row(location_description='AUTO / BOAT / RV DEALERSHIP'),
#  Row(location_description='CHA PARKING LOT/GROUNDS'),
#  Row(location_description='LOADING DOCK'),
#  Row(location_description='COACH HOUSE'),
#  Row(location_description='AIRPORT TERMINAL LOWER LEVEL - SECURE AREA'),
#  Row(location_description='CTA SUBWAY STATION'),
#  Row(location_description='COLLEGE/UNIVERSITY GROUNDS'),
#  Row(location_description='FIRE STATION'),
#  Row(location_description='YMCA'),
#  Row(location_description='SAVINGS AND LOAN'),
#  Row(location_description='CHA PARKING LOT'),
#  Row(location_description='HOSPITAL BUILDING / GROUNDS'),
#  Row(location_description='AIRPORT EXTERIOR - SECURE AREA'),
#  Row(location_description='JAIL / LOCK-UP FACILITY'),
#  Row(location_description='VEHICLE - DELIVERY TRUCK'),
#  Row(location_description='BOWLING ALLEY'),
#  Row(location_description='CONSTRUCTION SITE'),
#  Row(location_description='CTA PROPERTY'),
#  Row(location_description='SEWER'),
#  Row(location_description='VEHICLE - COMMERCIAL: TROLLEY BUS'),
#  Row(location_description='DELIVERY TRUCK'),
#  Row(location_description='PRAIRIE'),
#  Row(location_description='SPORTS ARENA / STADIUM'),
#  Row(location_description='HIGHWAY/EXPRESSWAY'),
#  Row(location_description='BAR OR TAVERN'),
#  Row(location_description='COLLEGE/UNIVERSITY RESIDENCE HALL'),
#  Row(location_description='GARAGE'),
#  Row(location_description='WOODED AREA'),
#  Row(location_description='HIGHWAY / EXPRESSWAY'),
#  Row(location_description='PARKING LOT/GARAGE(NON.RESID.)'),
#  Row(location_description='NURSING HOME/RETIREMENT HOME'),
#  Row(location_description='SCHOOL - PUBLIC BUILDING'),
#  Row(location_description='CTA TRACKS - RIGHT OF WAY'),
#  Row(location_description='VESTIBULE'),
#  Row(location_description='CHURCH/SYNAGOGUE/PLACE OF WORSHIP'),
#  Row(location_description='AIRPORT PARKING LOT'),
#  Row(location_description='LIVERY STAND OFFICE'),
#  Row(location_description='VACANT LOT / LAND'),
#  Row(location_description='CTA "L" TRAIN')]

# %%
unique_location_description.sort(key=lambda x: x.location_description or '')

# %%
unique_location_description
# Out:
# [Row(location_description=None),
#  Row(location_description='ABANDONED BUILDING'),
#  Row(location_description='AIRCRAFT'),
#  Row(location_description='AIRPORT BUILDING NON-TERMINAL - NON-SECURE AREA'),
#  Row(location_description='AIRPORT BUILDING NON-TERMINAL - SECURE AREA'),
#  Row(location_description='AIRPORT EXTERIOR - NON-SECURE AREA'),
#  Row(location_description='AIRPORT EXTERIOR - SECURE AREA'),
#  Row(location_description='AIRPORT PARKING LOT'),
#  Row(location_description='AIRPORT TERMINAL LOWER LEVEL - NON-SECURE AREA'),
#  Row(location_description='AIRPORT TERMINAL LOWER LEVEL - SECURE AREA'),
#  Row(location_description='AIRPORT TERMINAL MEZZANINE - NON-SECURE AREA'),
#  Row(location_description='AIRPORT TERMINAL UPPER LEVEL - NON-SECURE AREA'),
#  Row(location_description='AIRPORT TERMINAL UPPER LEVEL - SECURE AREA'),
#  Row(location_description='AIRPORT TRANSPORTATION SYSTEM (ATS)'),
#  Row(location_description='AIRPORT VENDING ESTABLISHMENT'),
#  Row(location_description='AIRPORT/AIRCRAFT'),
#  Row(location_description='ALLEY'),
#  Row(location_description='ANIMAL HOSPITAL'),
#  Row(location_description='APARTMENT'),
#  Row(location_description='APPLIANCE STORE'),
#  Row(location_description='ATHLETIC CLUB'),
#  Row(location_description='ATM (AUTOMATIC TELLER MACHINE)'),
#  Row(location_description='AUTO'),
#  Row(location_description='AUTO / BOAT / RV DEALERSHIP'),
#  Row(location_description='BANK'),
#  Row(location_description='BANQUET HALL'),
#  Row(location_description='BAR OR TAVERN'),
#  Row(location_description='BARBER SHOP/BEAUTY SALON'),
#  Row(location_description='BARBERSHOP'),
#  Row(location_description='BASEMENT'),
#  Row(location_description='BOAT / WATERCRAFT'),
#  Row(location_description='BOAT/WATERCRAFT'),
#  Row(location_description='BOWLING ALLEY'),
#  Row(location_description='BRIDGE'),
#  Row(location_description='CAR WASH'),
#  Row(location_description='CEMETARY'),
#  Row(location_description='CHA APARTMENT'),
#  Row(location_description='CHA BREEZEWAY'),
#  Row(location_description='CHA ELEVATOR'),
#  Row(location_description='CHA GROUNDS'),
#  Row(location_description='CHA HALLWAY'),
#  Row(location_description='CHA HALLWAY / STAIRWELL / ELEVATOR'),
#  Row(location_description='CHA HALLWAY/STAIRWELL/ELEVATOR'),
#  Row(location_description='CHA LOBBY'),
#  Row(location_description='CHA PARKING LOT'),
#  Row(location_description='CHA PARKING LOT / GROUNDS'),
#  Row(location_description='CHA PARKING LOT/GROUNDS'),
#  Row(location_description='CHA PLAY LOT'),
#  Row(location_description='CHA STAIRWELL'),
#  Row(location_description='CHURCH'),
#  Row(location_description='CHURCH / SYNAGOGUE / PLACE OF WORSHIP'),
#  Row(location_description='CHURCH PROPERTY'),
#  Row(location_description='CHURCH/SYNAGOGUE/PLACE OF WORSHIP'),
#  Row(location_description='CLEANERS/LAUNDROMAT'),
#  Row(location_description='CLEANING STORE'),
#  Row(location_description='CLUB'),
#  Row(location_description='COACH HOUSE'),
#  Row(location_description='COIN OPERATED MACHINE'),
#  Row(location_description='COLLEGE / UNIVERSITY - GROUNDS'),
#  Row(location_description='COLLEGE / UNIVERSITY - RESIDENCE HALL'),
#  Row(location_description='COLLEGE/UNIVERSITY GROUNDS'),
#  Row(location_description='COLLEGE/UNIVERSITY RESIDENCE HALL'),
#  Row(location_description='COMMERCIAL / BUSINESS OFFICE'),
#  Row(location_description='CONSTRUCTION SITE'),
#  Row(location_description='CONVENIENCE STORE'),
#  Row(location_description='COUNTY JAIL'),
#  Row(location_description='CREDIT UNION'),
#  Row(location_description='CTA "L" PLATFORM'),
#  Row(location_description='CTA "L" TRAIN'),
#  Row(location_description='CTA BUS'),
#  Row(location_description='CTA BUS STOP'),
#  Row(location_description='CTA GARAGE / OTHER PROPERTY'),
#  Row(location_description='CTA PARKING LOT / GARAGE / OTHER PROPERTY'),
#  Row(location_description='CTA PLATFORM'),
#  Row(location_description='CTA PROPERTY'),
#  Row(location_description='CTA STATION'),
#  Row(location_description='CTA SUBWAY STATION'),
#  Row(location_description='CTA TRACKS - RIGHT OF WAY'),
#  Row(location_description='CTA TRAIN'),
#  Row(location_description='CURRENCY EXCHANGE'),
#  Row(location_description='DAY CARE CENTER'),
#  Row(location_description='DELIVERY TRUCK'),
#  Row(location_description='DEPARTMENT STORE'),
#  Row(location_description='DRIVEWAY'),
#  Row(location_description='DRIVEWAY - RESIDENTIAL'),
#  Row(location_description='DRUG STORE'),
#  Row(location_description='DUMPSTER'),
#  Row(location_description='FACTORY / MANUFACTURING BUILDING'),
#  Row(location_description='FACTORY/MANUFACTURING BUILDING'),
#  Row(location_description='FARM'),
#  Row(location_description='FEDERAL BUILDING'),
#  Row(location_description='FIRE STATION'),
#  Row(location_description='FOREST PRESERVE'),
#  Row(location_description='FUNERAL PARLOR'),
#  Row(location_description='GANGWAY'),
#  Row(location_description='GARAGE'),
#  Row(location_description='GARAGE/AUTO REPAIR'),
#  Row(location_description='GAS STATION'),
#  Row(location_description='GAS STATION DRIVE/PROP.'),
#  Row(location_description='GOVERNMENT BUILDING'),
#  Row(location_description='GOVERNMENT BUILDING / PROPERTY'),
#  Row(location_description='GOVERNMENT BUILDING/PROPERTY'),
#  Row(location_description='GROCERY FOOD STORE'),
#  Row(location_description='HALLWAY'),
#  Row(location_description='HIGHWAY / EXPRESSWAY'),
#  Row(location_description='HIGHWAY/EXPRESSWAY'),
#  Row(location_description='HORSE STABLE'),
#  Row(location_description='HOSPITAL'),
#  Row(location_description='HOSPITAL BUILDING / GROUNDS'),
#  Row(location_description='HOSPITAL BUILDING/GROUNDS'),
#  Row(location_description='HOTEL'),
#  Row(location_description='HOTEL / MOTEL'),
#  Row(location_description='HOTEL/MOTEL'),
#  Row(location_description='HOUSE'),
#  Row(location_description='JAIL / LOCK-UP FACILITY'),
#  Row(location_description='KENNEL'),
#  Row(location_description='LAGOON'),
#  Row(location_description='LAKE'),
#  Row(location_description='LAKEFRONT / WATERFRONT / RIVERBANK'),
#  Row(location_description='LAKEFRONT/WATERFRONT/RIVERBANK'),
#  Row(location_description='LAUNDRY ROOM'),
#  Row(location_description='LIBRARY'),
#  Row(location_description='LIQUOR STORE'),
#  Row(location_description='LIVERY AUTO'),
#  Row(location_description='LIVERY STAND OFFICE'),
#  Row(location_description='LOADING DOCK'),
#  Row(location_description='MEDICAL / DENTAL OFFICE'),
#  Row(location_description='MEDICAL/DENTAL OFFICE'),
#  Row(location_description='MOTEL'),
#  Row(location_description='MOVIE HOUSE / THEATER'),
#  Row(location_description='MOVIE HOUSE/THEATER'),
#  Row(location_description='NEWSSTAND'),
#  Row(location_description='NURSING / RETIREMENT HOME'),
#  Row(location_description='NURSING HOME'),
#  Row(location_description='NURSING HOME/RETIREMENT HOME'),
#  Row(location_description='OFFICE'),
#  Row(location_description='OTHER'),
#  Row(location_description='OTHER (SPECIFY)'),
#  Row(location_description='OTHER COMMERCIAL TRANSPORTATION'),
#  Row(location_description='OTHER RAILROAD PROP / TRAIN DEPOT'),
#  Row(location_description='OTHER RAILROAD PROPERTY / TRAIN DEPOT'),
#  Row(location_description='PARK PROPERTY'),
#  Row(location_description='PARKING LOT'),
#  Row(location_description='PARKING LOT / GARAGE (NON RESIDENTIAL)'),
#  Row(location_description='PARKING LOT/GARAGE(NON.RESID.)'),
#  Row(location_description='PAWN SHOP'),
#  Row(location_description='POLICE FACILITY / VEHICLE PARKING LOT'),
#  Row(location_description='POLICE FACILITY/VEH PARKING LOT'),
#  Row(location_description='POOL ROOM'),
#  Row(location_description='PORCH'),
#  Row(location_description='PRAIRIE'),
#  Row(location_description='PUBLIC HIGH SCHOOL'),
#  Row(location_description='RAILROAD PROPERTY'),
#  Row(location_description='RESIDENCE'),
#  Row(location_description='RESIDENCE - GARAGE'),
#  Row(location_description='RESIDENCE - PORCH / HALLWAY'),
#  Row(location_description='RESIDENCE - YARD (FRONT / BACK)'),
#  Row(location_description='RESIDENCE PORCH/HALLWAY'),
#  Row(location_description='RESIDENCE-GARAGE'),
#  Row(location_description='RESIDENTIAL YARD (FRONT/BACK)'),
#  Row(location_description='RESTAURANT'),
#  Row(location_description='RETAIL STORE'),
#  Row(location_description='RIVER'),
#  Row(location_description='RIVER BANK'),
#  Row(location_description='ROOMING HOUSE'),
#  Row(location_description='SAVINGS AND LOAN'),
#  Row(location_description='SCHOOL - PRIVATE BUILDING'),
#  Row(location_description='SCHOOL - PRIVATE GROUNDS'),
#  Row(location_description='SCHOOL - PUBLIC BUILDING'),
#  Row(location_description='SCHOOL - PUBLIC GROUNDS'),
#  Row(location_description='SCHOOL YARD'),
#  Row(location_description='SCHOOL, PRIVATE, BUILDING'),
#  Row(location_description='SCHOOL, PRIVATE, GROUNDS'),
#  Row(location_description='SCHOOL, PUBLIC, BUILDING'),
#  Row(location_description='SCHOOL, PUBLIC, GROUNDS'),
#  Row(location_description='SEWER'),
#  Row(location_description='SIDEWALK'),
#  Row(location_description='SMALL RETAIL STORE'),
#  Row(location_description='SPORTS ARENA / STADIUM'),
#  Row(location_description='SPORTS ARENA/STADIUM'),
#  Row(location_description='STAIRWELL'),
#  Row(location_description='STREET'),
#  Row(location_description='TAVERN'),
#  Row(location_description='TAVERN / LIQUOR STORE'),
#  Row(location_description='TAVERN/LIQUOR STORE'),
#  Row(location_description='TAXI CAB'),
#  Row(location_description='TAXICAB'),
#  Row(location_description='TRAILER'),
#  Row(location_description='TRUCK'),
#  Row(location_description='TRUCKING TERMINAL'),
#  Row(location_description='VACANT LOT'),
#  Row(location_description='VACANT LOT / LAND'),
#  Row(location_description='VACANT LOT/LAND'),
#  Row(location_description='VEHICLE - COMMERCIAL'),
#  Row(location_description='VEHICLE - COMMERCIAL: ENTERTAINMENT / PARTY BUS'),
#  Row(location_description='VEHICLE - COMMERCIAL: TROLLEY BUS'),
#  Row(location_description='VEHICLE - DELIVERY TRUCK'),
#  Row(location_description='VEHICLE - OTHER RIDE SERVICE'),
#  Row(location_description='VEHICLE - OTHER RIDE SHARE SERVICE (E.G., UBER, LYFT)'),
#  Row(location_description='VEHICLE - OTHER RIDE SHARE SERVICE (LYFT, UBER, ETC.)'),
#  Row(location_description='VEHICLE NON-COMMERCIAL'),
#  Row(location_description='VEHICLE-COMMERCIAL'),
#  Row(location_description='VEHICLE-COMMERCIAL - ENTERTAINMENT/PARTY BUS'),
#  Row(location_description='VEHICLE-COMMERCIAL - TROLLEY BUS'),
#  Row(location_description='VESTIBULE'),
#  Row(location_description='WAREHOUSE'),
#  Row(location_description='WOODED AREA'),
#  Row(location_description='YARD'),
#  Row(location_description='YMCA')]

# %%
#schema for dataframe
schema = StructType([
  StructField('id', IntegerType()),
  StructField('location_description', StringType())
  ])

# %%
#create for each unique location description an unique int and put it on a list
location_description_code = []
df_location_description = spark.createDataFrame(spark.sparkContext.emptyRDD(),schema)

for i in unique_location_description:
    if i.location_description != None:
        location_description_code.append(i.location_description)
        index = location_description_code.index(i.location_description)  
        df_temp = spark.createDataFrame([(index, i.location_description)],("id", "location_description"))
        df_location_description = df_location_description.union(df_temp)
    
    #print(i.description)

# %%
collection_location_description.drop()

# %%
#write the infos into the mongo db
df_location_description.write.format("mongo").option("uri","mongodb://mongo:27017/mydb.location_description").mode("append").save()

# %%
#test = spark.read.format("mongo").option("uri","mongodb://mongo:27017/mydb.location_description").load()
#test.show(20)

# %%
# convert the string primary type into integer
myfunc =  UserDefinedFunction(lambda x: location_description_code.index(x) if x in location_description_code else -1)
df = df.withColumn('location_description_int', myfunc(col('location_description')))

# %%
df.show(10)
# Out:
# +------+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+------------+--------------------+-------------+--------------------+--------------------+----+----+---------------+----------------+------------------------+
# |arrest|               block|case_number|community_area|                date|         description|district|domestic|    latitude|location_description|    longitude|        primary_type|          updated_on|ward|year|description_int|primary_type_int|location_description_int|
# +------+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+------------+--------------------+-------------+--------------------+--------------------+----+----+---------------+----------------+------------------------+
# | false| 050XX N ASHLAND AVE|   JB152500|             3|2001-01-01T00:00:...|AGG SEX ASSLT OF ...|     020|   false|        null|           RESIDENCE|         null|OFFENSE INVOLVING...|2018-10-27T16:00:...|  47|2001|             19|              24|                     152|
# | false|   018XX N TALMAN AV|    G055473|          null|2001-01-01T00:00:...|      $500 AND UNDER|     014|   false|41.914955409|              STREET|-87.693605188|               THEFT|2015-08-17T15:03:...|null|2001|              1|              34|                     180|
# | false|    034XX W ADAMS ST|    G057402|          null|2001-01-01T00:00:...|   CREDIT CARD FRAUD|     011|   false| 41.87821192|           RESIDENCE|-87.711432075|  DECEPTIVE PRACTICE|2015-08-17T15:03:...|null|2001|            184|               9|                     152|
# | false|  062XX N PULASKI RD|    G061760|          null|2001-01-01T00:00:...|   CREDIT CARD FRAUD|     017|   false|41.995267432|  SMALL RETAIL STORE|-87.729044138|  DECEPTIVE PRACTICE|2015-08-17T15:03:...|null|2001|            184|               9|                     176|
# | false|012XX N SPRINGFIE...|    G067736|          null|2001-01-01T00:00:...|              SIMPLE|     025|   false|41.903597909|           RESIDENCE|-87.724042825|             ASSAULT|2015-08-17T15:03:...|null|2001|            435|               1|                     152|
# | false|045XX N CLARENDON AV|    G000065|          null|2001-01-01T00:00:...|          TO VEHICLE|     019|   false|41.963705611|              STREET|-87.650116531|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            477|               6|                     180|
# | false|  026XX S INDIANA AV|    G000355|          null|2001-01-01T00:00:...|         TO PROPERTY|     002|   false|41.844745115|           APARTMENT|-87.621968071|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            472|               6|                      17|
# | false|       036XX W 80 ST|    G000610|          null|2001-01-01T00:00:...|          TO VEHICLE|     008|   false|41.747712773|              STREET|-87.712370684|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            477|               6|                     180|
# | false| 109XX S LONGWOOD DR|    G000070|          null|2001-01-01T00:00:...|         TO PROPERTY|     022|   false|41.694977232|           APARTMENT|-87.671447845|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            472|               6|                      17|
# | false| 0000X W ILLINOIS ST|    G000802|          null|2001-01-01T00:00:...|          TO VEHICLE|     018|   false|41.890741624|PARKING LOT/GARAG...|-87.628671125|     CRIMINAL DAMAGE|2015-08-17T15:03:...|null|2001|            477|               6|                     143|
# +------+--------------------+-----------+--------------+--------------------+--------------------+--------+--------+------------+--------------------+-------------+--------------------+--------------------+----+----+---------------+----------------+------------------------+
# only showing top 10 rows

# %%
# drop the columns with the string values
df = df.drop('description')
df = df.drop('primary_type')
df = df.drop('location_description')

# %% [markdown]
# ## Drop null values from columne

# %%
# show the number of null values from each columne
df.select([count(when(col(c).isNull(), c)).alias(c) for c in df.columns]).show()

# %%
# drop the columns where latitude is null
df = df.na.drop(subset=["latitude"])

# %% [markdown]
# ## Convert data string to datetime

# %%
df.show(10)

# %%
# convert the date into datetime format
myfunc =  UserDefinedFunction(lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f'), TimestampType())
df = df.withColumn('date_time', myfunc(col('date')))

# %%
df.show(5)

# %%
#convert the date_time into date format
myfunc =  UserDefinedFunction(lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f'), DateType())
df = df.withColumn('date', myfunc(col('date')))

# %%
df.show(5)

# %% [markdown]
# ### Save Cleaned Data to Mongo

# %%
collection_crime_clean.drop()

# %%
#write the cleaned dataframe into a new mongo collection
df.write.format("mongo").option("uri","mongodb://mongo:27017/mydb.chicago_crime_cleaned").mode("append").save()

# %%
spark.stop()
